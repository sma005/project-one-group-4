# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import numpy as np
import requests
import time
import json
import string
from datetime import date 
from scipy.stats import linregress

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
#Notes: https://data.cdc.gov/Nutrition-Physical-Activity-and-Obesity/Nutrition-Physical-Activity-and-Obesity-Behavioral/hn4x-zwk7

# %%
#Import the API Key
#from api_key import api_key
#Don't need API Key

#import data
#url = "https://data.cdc.gov/resource/hn4x-zwk7.json"
data_df = pd.read_csv(r"Resources\Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System_20231101.csv")

#response = requests.get(url)
#data = response.json()

#data_df.info()
data_df
# Out:
#        YearStart  YearEnd LocationAbbr  LocationDesc  \
# 0           2020     2020           US      National
# 1           2014     2014           GU          Guam
# 2           2013     2013           US      National
# 3           2013     2013           US      National
# 4           2015     2015           US      National
# ...          ...      ...          ...           ...
# 88624       2021     2021           ND  North Dakota
# 88625       2021     2021           PR   Puerto Rico
# 88626       2021     2021           WI     Wisconsin
# 88627       2021     2021           UT          Utah
# 88628       2021     2021           US      National
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System        Physical Activity
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System        Physical Activity
# ...                                           ...                      ...
# 88624  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 88625  Behavioral Risk Factor Surveillance System        Physical Activity
# 88626  Behavioral Risk Factor Surveillance System        Physical Activity
# 88627  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 88628  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                                   Topic  \
# 0          Physical Activity - Behavior
# 1               Obesity / Weight Status
# 2               Obesity / Weight Status
# 3               Obesity / Weight Status
# 4          Physical Activity - Behavior
# ...                                 ...
# 88624  Fruits and Vegetables - Behavior
# 88625      Physical Activity - Behavior
# 88626      Physical Activity - Behavior
# 88627  Fruits and Vegetables - Behavior
# 88628      Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults who engage in no leisure-tim...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 3      Percent of adults aged 18 years and older who ...              NaN
# 4      Percent of adults who achieve at least 300 min...              NaN
# ...                                                  ...              ...
# 88624  Percent of adults who report consuming vegetab...              NaN
# 88625  Percent of adults who engage in no leisure-tim...              NaN
# 88626  Percent of adults who engage in no leisure-tim...              NaN
# 88627  Percent of adults who report consuming fruit l...              NaN
# 88628  Percent of adults who engage in no leisure-tim...              NaN
#
#       Data_Value_Type  ...                                GeoLocation  \
# 0               Value  ...                                        NaN
# 1               Value  ...                    (13.444304, 144.793731)
# 2               Value  ...                                        NaN
# 3               Value  ...                                        NaN
# 4               Value  ...                                        NaN
# ...               ...  ...                                        ...
# 88624           Value  ...   (47.47531977900047, -100.11842104899966)
# 88625           Value  ...                    (18.220833, -66.590149)
# 88626           Value  ...    (44.39319117400049, -89.81637074199966)
# 88627           Value  ...  (39.360700171000474, -111.58713063499971)
# 88628           Value  ...                                        NaN
#
#        ClassID TopicID QuestionID  DataValueTypeID  LocationID  \
# 0           PA     PA1       Q047            VALUE          59
# 1          OWS    OWS1       Q036            VALUE          66
# 2          OWS    OWS1       Q036            VALUE          59
# 3          OWS    OWS1       Q037            VALUE          59
# 4           PA     PA1       Q045            VALUE          59
# ...        ...     ...        ...              ...         ...
# 88624       FV     FV1       Q019            VALUE          38
# 88625       PA     PA1       Q047            VALUE          72
# 88626       PA     PA1       Q047            VALUE          55
# 88627       FV     FV1       Q018            VALUE          49
# 88628       PA     PA1       Q047            VALUE          59
#
#        StratificationCategory1       Stratification1  \
# 0               Race/Ethnicity              Hispanic
# 1                    Education  High school graduate
# 2                       Income     $50,000 - $74,999
# 3                       Income     Data not reported
# 4                       Income     Less than $15,000
# ...                        ...                   ...
# 88624                   Gender                  Male
# 88625                   Income     $35,000 - $49,999
# 88626                   Income    $75,000 or greater
# 88627                   Income     $50,000 - $74,999
# 88628                   Income     Data not reported
#
#       StratificationCategoryId1 StratificationID1
# 0                          RACE           RACEHIS
# 1                           EDU         EDUHSGRAD
# 2                           INC           INC5075
# 3                           INC             INCNR
# 4                           INC         INCLESS15
# ...                         ...               ...
# 88624                       GEN              MALE
# 88625                       INC           INC3550
# 88626                       INC         INC75PLUS
# 88627                       INC           INC5075
# 88628                       INC             INCNR
#
# [88629 rows x 33 columns]

# %%
list_of_categories = data_df['StratificationCategory1'].unique()
list_of_categories
# Out:
# array(['Race/Ethnicity', 'Education', 'Income', 'Age (years)', 'Gender',
#        'Total', nan], dtype=object)

# %%
ethnicity_df = [data_df['StratificationCategory1'] == 'Race/Ethnicity']
ethnicity_df
# Out:
# [0         True
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  88624    False
#  88625    False
#  88626    False
#  88627    False
#  88628    False
#  Name: StratificationCategory1, Length: 88629, dtype: bool]

# %%
education_df = data_df[data_df['StratificationCategory1'] == 'Education']
education_df.head()
# Out:
#     YearStart  YearEnd LocationAbbr          LocationDesc  \
# 1        2014     2014           GU                  Guam
# 7        2012     2012           DC  District of Columbia
# 10       2015     2015           GU                  Guam
# 21       2012     2012           US              National
# 43       2016     2016           RI          Rhode Island
#
#                                     Datasource                    Class  \
# 1   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 7   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 10  Behavioral Risk Factor Surveillance System        Physical Activity
# 21  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 43  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                            Topic  \
# 1        Obesity / Weight Status
# 7        Obesity / Weight Status
# 10  Physical Activity - Behavior
# 21       Obesity / Weight Status
# 43       Obesity / Weight Status
#
#                                              Question  Data_Value_Unit  \
# 1   Percent of adults aged 18 years and older who ...              NaN
# 7   Percent of adults aged 18 years and older who ...              NaN
# 10  Percent of adults who engage in no leisure-tim...              NaN
# 21  Percent of adults aged 18 years and older who ...              NaN
# 43  Percent of adults aged 18 years and older who ...              NaN
#
#    Data_Value_Type  ...                    GeoLocation  ClassID TopicID  \
# 1            Value  ...        (13.444304, 144.793731)      OWS    OWS1
# 7            Value  ...  (38.890371385, -77.031961127)      OWS    OWS1
# 10           Value  ...        (13.444304, 144.793731)       PA     PA1
# 21           Value  ...                            NaN      OWS    OWS1
# 43           Value  ...  (41.708280193, -71.522470314)      OWS    OWS1
#
#    QuestionID  DataValueTypeID  LocationID  StratificationCategory1  \
# 1        Q036            VALUE          66                Education
# 7        Q036            VALUE          11                Education
# 10       Q047            VALUE          66                Education
# 21       Q037            VALUE          59                Education
# 43       Q036            VALUE          44                Education
#
#                      Stratification1 StratificationCategoryId1  \
# 1               High school graduate                       EDU
# 7              Less than high school                       EDU
# 10              High school graduate                       EDU
# 21  Some college or technical school                       EDU
# 43                  College graduate                       EDU
#
#    StratificationID1
# 1          EDUHSGRAD
# 7              EDUHS
# 10         EDUHSGRAD
# 21          EDUCOTEC
# 43         EDUCOGRAD
#
# [5 rows x 33 columns]

# %%
income_df = data_df[data_df['StratificationCategory1'] == 'Income']
income_df.head()
# Out:
#     YearStart  YearEnd LocationAbbr LocationDesc  \
# 2        2013     2013           US     National
# 3        2013     2013           US     National
# 4        2015     2015           US     National
# 8        2015     2015           PR  Puerto Rico
# 13       2012     2012           WY      Wyoming
#
#                                     Datasource                    Class  \
# 2   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4   Behavioral Risk Factor Surveillance System        Physical Activity
# 8   Behavioral Risk Factor Surveillance System        Physical Activity
# 13  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                            Topic  \
# 2        Obesity / Weight Status
# 3        Obesity / Weight Status
# 4   Physical Activity - Behavior
# 8   Physical Activity - Behavior
# 13  Physical Activity - Behavior
#
#                                              Question  Data_Value_Unit  \
# 2   Percent of adults aged 18 years and older who ...              NaN
# 3   Percent of adults aged 18 years and older who ...              NaN
# 4   Percent of adults who achieve at least 300 min...              NaN
# 8   Percent of adults who engage in no leisure-tim...              NaN
# 13  Percent of adults who engage in no leisure-tim...              NaN
#
#    Data_Value_Type  ...                     GeoLocation  ClassID TopicID  \
# 2            Value  ...                             NaN      OWS    OWS1
# 3            Value  ...                             NaN      OWS    OWS1
# 4            Value  ...                             NaN       PA     PA1
# 8            Value  ...         (18.220833, -66.590149)       PA     PA1
# 13           Value  ...  (43.235541343, -108.109830353)       PA     PA1
#
#    QuestionID  DataValueTypeID  LocationID  StratificationCategory1  \
# 2        Q036            VALUE          59                   Income
# 3        Q037            VALUE          59                   Income
# 4        Q045            VALUE          59                   Income
# 8        Q047            VALUE          72                   Income
# 13       Q047            VALUE          56                   Income
#
#       Stratification1 StratificationCategoryId1 StratificationID1
# 2   $50,000 - $74,999                       INC           INC5075
# 3   Data not reported                       INC             INCNR
# 4   Less than $15,000                       INC         INCLESS15
# 8   $25,000 - $34,999                       INC           INC2535
# 13  Less than $15,000                       INC         INCLESS15
#
# [5 rows x 33 columns]

# %%
age_df = data_df[data_df['StratificationCategory1'] == 'Age (years)']
age_df.head()
# Out:
#     YearStart  YearEnd LocationAbbr LocationDesc  \
# 9        2011     2011           AL      Alabama
# 17       2015     2015           GU         Guam
# 24       2015     2015           PR  Puerto Rico
# 25       2011     2011           US     National
# 29       2015     2015           PR  Puerto Rico
#
#                                     Datasource                    Class  \
# 9   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 17  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 24  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 25  Behavioral Risk Factor Surveillance System        Physical Activity
# 29  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                            Topic  \
# 9        Obesity / Weight Status
# 17       Obesity / Weight Status
# 24       Obesity / Weight Status
# 25  Physical Activity - Behavior
# 29  Physical Activity - Behavior
#
#                                              Question  Data_Value_Unit  \
# 9   Percent of adults aged 18 years and older who ...              NaN
# 17  Percent of adults aged 18 years and older who ...              NaN
# 24  Percent of adults aged 18 years and older who ...              NaN
# 25  Percent of adults who engage in no leisure-tim...              NaN
# 29  Percent of adults who engage in no leisure-tim...              NaN
#
#    Data_Value_Type  ...                    GeoLocation  ClassID TopicID  \
# 9            Value  ...  (32.840571122, -86.631860762)      OWS    OWS1
# 17           Value  ...        (13.444304, 144.793731)      OWS    OWS1
# 24           Value  ...        (18.220833, -66.590149)      OWS    OWS1
# 25           Value  ...                            NaN       PA     PA1
# 29           Value  ...        (18.220833, -66.590149)       PA     PA1
#
#    QuestionID  DataValueTypeID  LocationID  StratificationCategory1  \
# 9        Q036            VALUE           1              Age (years)
# 17       Q036            VALUE          66              Age (years)
# 24       Q037            VALUE          72              Age (years)
# 25       Q047            VALUE          59              Age (years)
# 29       Q047            VALUE          72              Age (years)
#
#    Stratification1 StratificationCategoryId1 StratificationID1
# 9          25 - 34                     AGEYR         AGEYR2534
# 17         55 - 64                     AGEYR         AGEYR5564
# 24         55 - 64                     AGEYR         AGEYR5564
# 25         18 - 24                     AGEYR         AGEYR1824
# 29         45 - 54                     AGEYR         AGEYR4554
#
# [5 rows x 33 columns]

# %%
gender_df = data_df[data_df['StratificationCategory1'] == 'Gender']
gender_df.head()
# Out:
#     YearStart  YearEnd LocationAbbr LocationDesc  \
# 23       2013     2013           US     National
# 32       2020     2020           ME        Maine
# 36       2016     2016           WY      Wyoming
# 41       2016     2016           NY     New York
# 49       2016     2016           AR     Arkansas
#
#                                     Datasource                    Class  \
# 23  Behavioral Risk Factor Surveillance System        Physical Activity
# 32  Behavioral Risk Factor Surveillance System        Physical Activity
# 36  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 41  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 49  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                            Topic  \
# 23  Physical Activity - Behavior
# 32  Physical Activity - Behavior
# 36       Obesity / Weight Status
# 41       Obesity / Weight Status
# 49       Obesity / Weight Status
#
#                                              Question  Data_Value_Unit  \
# 23  Percent of adults who engage in no leisure-tim...              NaN
# 32  Percent of adults who engage in no leisure-tim...              NaN
# 36  Percent of adults aged 18 years and older who ...              NaN
# 41  Percent of adults aged 18 years and older who ...              NaN
# 49  Percent of adults aged 18 years and older who ...              NaN
#
#    Data_Value_Type  ...                               GeoLocation  ClassID  \
# 23           Value  ...                                       NaN       PA
# 32           Value  ...  (45.254228894000505, -68.98503133599962)       PA
# 36           Value  ...            (43.235541343, -108.109830353)      OWS
# 41           Value  ...             (42.827001032, -75.543970427)      OWS
# 49           Value  ...             (34.748650124, -92.274490743)      OWS
#
#    TopicID QuestionID  DataValueTypeID  LocationID  StratificationCategory1  \
# 23     PA1       Q047            VALUE          59                   Gender
# 32     PA1       Q047            VALUE          23                   Gender
# 36    OWS1       Q037            VALUE          56                   Gender
# 41    OWS1       Q036            VALUE          36                   Gender
# 49    OWS1       Q037            VALUE           5                   Gender
#
#    Stratification1 StratificationCategoryId1 StratificationID1
# 23          Female                       GEN            FEMALE
# 32            Male                       GEN              MALE
# 36          Female                       GEN            FEMALE
# 41            Male                       GEN              MALE
# 49            Male                       GEN              MALE
#
# [5 rows x 33 columns]

# %%
totals_df = data_df[data_df['StratificationCategory1'] == 'Total']
totals_df.head()
# Out:
#      YearStart  YearEnd LocationAbbr   LocationDesc  \
# 31        2015     2015           PR    Puerto Rico
# 53        2016     2016           NM     New Mexico
# 76        2015     2015           PR    Puerto Rico
# 93        2016     2016           NH  New Hampshire
# 110       2016     2016           AZ        Arizona
#
#                                      Datasource                    Class  \
# 31   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 53   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 76   Behavioral Risk Factor Surveillance System        Physical Activity
# 93   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 110  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                             Topic  \
# 31        Obesity / Weight Status
# 53        Obesity / Weight Status
# 76   Physical Activity - Behavior
# 93        Obesity / Weight Status
# 110  Physical Activity - Behavior
#
#                                               Question  Data_Value_Unit  \
# 31   Percent of adults aged 18 years and older who ...              NaN
# 53   Percent of adults aged 18 years and older who ...              NaN
# 76   Percent of adults who engage in muscle-strengt...              NaN
# 93   Percent of adults aged 18 years and older who ...              NaN
# 110  Percent of adults who engage in no leisure-tim...              NaN
#
#     Data_Value_Type  ...                     GeoLocation  ClassID TopicID  \
# 31            Value  ...         (18.220833, -66.590149)      OWS    OWS1
# 53            Value  ...  (34.520880952, -106.240580985)      OWS    OWS1
# 76            Value  ...         (18.220833, -66.590149)       PA     PA1
# 93            Value  ...    (43.655950113, -71.50036092)      OWS    OWS1
# 110           Value  ...   (34.86597028, -111.763811277)       PA     PA1
#
#     QuestionID  DataValueTypeID  LocationID  StratificationCategory1  \
# 31        Q036            VALUE          72                    Total
# 53        Q036            VALUE          35                    Total
# 76        Q046            VALUE          72                    Total
# 93        Q036            VALUE          33                    Total
# 110       Q047            VALUE           4                    Total
#
#     Stratification1 StratificationCategoryId1 StratificationID1
# 31            Total                       OVR           OVERALL
# 53            Total                       OVR           OVERALL
# 76            Total                       OVR           OVERALL
# 93            Total                       OVR           OVERALL
# 110           Total                       OVR           OVERALL
#
# [5 rows x 33 columns]

# %%
#response.content
age_df = data_df[data_df['StratificationCategory1'] == 'Age (years)']
age_df.head()
# Out:
#     YearStart  YearEnd LocationAbbr LocationDesc  \
# 9        2011     2011           AL      Alabama
# 17       2015     2015           GU         Guam
# 24       2015     2015           PR  Puerto Rico
# 25       2011     2011           US     National
# 29       2015     2015           PR  Puerto Rico
#
#                                     Datasource                    Class  \
# 9   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 17  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 24  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 25  Behavioral Risk Factor Surveillance System        Physical Activity
# 29  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                            Topic  \
# 9        Obesity / Weight Status
# 17       Obesity / Weight Status
# 24       Obesity / Weight Status
# 25  Physical Activity - Behavior
# 29  Physical Activity - Behavior
#
#                                              Question  Data_Value_Unit  \
# 9   Percent of adults aged 18 years and older who ...              NaN
# 17  Percent of adults aged 18 years and older who ...              NaN
# 24  Percent of adults aged 18 years and older who ...              NaN
# 25  Percent of adults who engage in no leisure-tim...              NaN
# 29  Percent of adults who engage in no leisure-tim...              NaN
#
#    Data_Value_Type  ...                    GeoLocation  ClassID TopicID  \
# 9            Value  ...  (32.840571122, -86.631860762)      OWS    OWS1
# 17           Value  ...        (13.444304, 144.793731)      OWS    OWS1
# 24           Value  ...        (18.220833, -66.590149)      OWS    OWS1
# 25           Value  ...                            NaN       PA     PA1
# 29           Value  ...        (18.220833, -66.590149)       PA     PA1
#
#    QuestionID  DataValueTypeID  LocationID  StratificationCategory1  \
# 9        Q036            VALUE           1              Age (years)
# 17       Q036            VALUE          66              Age (years)
# 24       Q037            VALUE          72              Age (years)
# 25       Q047            VALUE          59              Age (years)
# 29       Q047            VALUE          72              Age (years)
#
#    Stratification1 StratificationCategoryId1 StratificationID1
# 9          25 - 34                     AGEYR         AGEYR2534
# 17         55 - 64                     AGEYR         AGEYR5564
# 24         55 - 64                     AGEYR         AGEYR5564
# 25         18 - 24                     AGEYR         AGEYR1824
# 29         45 - 54                     AGEYR         AGEYR4554
#
# [5 rows x 33 columns]

# %%
# Convert data into a Pandas DataFrame
#data_df = pd.DataFrame(data)

#data_df = data_df[['yearend','locationabbr','question','data_value','sample_size','age_years','StratificationCategory1','Stratification1']]
data_df = data_df[['YearEnd','LocationAbbr','Question','Data_Value','Sample_Size','Race/Ethnicity','Education','Gender','StratificationCategory1','Stratification1']]
#data_df['data_value'] = data_df.data_value.astype(float)
#data_df['sample_size'] = data_df.sample_size.astype(float)

#data_df = data_df[data_df['sample_size'].notna()]

data_df.info()
# Show Record Count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88629 entries, 0 to 88628
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   YearEnd                  88629 non-null  int64
#  1   LocationAbbr             88629 non-null  object
#  2   Question                 88629 non-null  object
#  3   Data_Value               79851 non-null  float64
#  4   Sample_Size              79851 non-null  float64
#  5   Race/Ethnicity           25320 non-null  object
#  6   Education                12660 non-null  object
#  7   Gender                   6330 non-null   object
#  8   StratificationCategory1  88620 non-null  object
#  9   Stratification1          88620 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 6.8+ MB

# %%
#Add calculated number of obese people
data_df['calculated_num_obese'] = round(data_df['Sample_Size'] * data_df['Data_Value'] * .01)
data_df.head()
# Out:
# C:\Users\Steve\AppData\Local\Temp\ipykernel_52792\2666077773.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df['calculated_num_obese'] = round(data_df['Sample_Size'] * data_df['Data_Value'] * .01)
#    YearEnd LocationAbbr                                           Question  \
# 0     2020           US  Percent of adults who engage in no leisure-tim...
# 1     2014           GU  Percent of adults aged 18 years and older who ...
# 2     2013           US  Percent of adults aged 18 years and older who ...
# 3     2013           US  Percent of adults aged 18 years and older who ...
# 4     2015           US  Percent of adults who achieve at least 300 min...
#
#    Data_Value  Sample_Size Race/Ethnicity             Education Gender  \
# 0        30.6      31255.0       Hispanic                   NaN    NaN
# 1        29.3        842.0            NaN  High school graduate    NaN
# 2        28.8      62562.0            NaN                   NaN    NaN
# 3        32.7      60069.0            NaN                   NaN    NaN
# 4        26.6      30904.0            NaN                   NaN    NaN
#
#   StratificationCategory1       Stratification1  calculated_num_obese
# 0          Race/Ethnicity              Hispanic                9564.0
# 1               Education  High school graduate                 247.0
# 2                  Income     $50,000 - $74,999               18018.0
# 3                  Income     Data not reported               19643.0
# 4                  Income     Less than $15,000                8220.0

# %%
num_of_participants = data_df['Sample_Size'].sum()
num_of_participants
# Out:
# 291999859.0

# %%
#These are the questions this dataset answers
list_of_questions = data_df['Question'].unique()
print(sorted(list_of_questions))
# Out:
# ['Percent of adults aged 18 years and older who have an overweight classification', 'Percent of adults aged 18 years and older who have obesity', 'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic activity (or an equivalent combination)', 'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic physical activity and engage in muscle-strengthening activities on 2 or more days a week', 'Percent of adults who achieve at least 300 minutes a week of moderate-intensity aerobic physical activity or 150 minutes a week of vigorous-intensity aerobic activity (or an equivalent combination)', 'Percent of adults who engage in muscle-strengthening activities on 2 or more days a week', 'Percent of adults who engage in no leisure-time physical activity', 'Percent of adults who report consuming fruit less than one time daily', 'Percent of adults who report consuming vegetables less than one time daily']

# %%
overweight_df = data_df[data_df['Question'] == 'Percent of adults aged 18 years and older who have an overweight classification']
overweight_df.head()
# Out:
#     YearEnd LocationAbbr                                           Question  \
# 3      2013           US  Percent of adults aged 18 years and older who ...
# 6      2012           WY  Percent of adults aged 18 years and older who ...
# 11     2015           RI  Percent of adults aged 18 years and older who ...
# 16     2015           GU  Percent of adults aged 18 years and older who ...
# 21     2012           US  Percent of adults aged 18 years and older who ...
#
#     Data_Value  Sample_Size                 Race/Ethnicity  \
# 3         32.7      60069.0                            NaN
# 6         48.5         69.0  American Indian/Alaska Native
# 11        40.2        354.0                       Hispanic
# 16         NaN          NaN                          Other
# 21        35.1     120032.0                            NaN
#
#                            Education Gender StratificationCategory1  \
# 3                                NaN    NaN                  Income
# 6                                NaN    NaN          Race/Ethnicity
# 11                               NaN    NaN          Race/Ethnicity
# 16                               NaN    NaN          Race/Ethnicity
# 21  Some college or technical school    NaN               Education
#
#                      Stratification1  calculated_num_obese
# 3                  Data not reported               19643.0
# 6      American Indian/Alaska Native                  33.0
# 11                          Hispanic                 142.0
# 16                             Other                   NaN
# 21  Some college or technical school               42131.0

# %%
obese_df = data_df[data_df['Question'] == 'Percent of adults aged 18 years and older who have obesity']
obese_df.head()
# Out:
#     YearEnd LocationAbbr                                           Question  \
# 1      2014           GU  Percent of adults aged 18 years and older who ...
# 2      2013           US  Percent of adults aged 18 years and older who ...
# 7      2012           DC  Percent of adults aged 18 years and older who ...
# 9      2011           AL  Percent of adults aged 18 years and older who ...
# 12     2011           US  Percent of adults aged 18 years and older who ...
#
#     Data_Value  Sample_Size                 Race/Ethnicity  \
# 1         29.3        842.0                            NaN
# 2         28.8      62562.0                            NaN
# 7         31.6        243.0                            NaN
# 9         35.2        598.0                            NaN
# 12        35.4       6649.0  American Indian/Alaska Native
#
#                 Education Gender StratificationCategory1  \
# 1    High school graduate    NaN               Education
# 2                     NaN    NaN                  Income
# 7   Less than high school    NaN               Education
# 9                     NaN    NaN             Age (years)
# 12                    NaN    NaN          Race/Ethnicity
#
#                   Stratification1  calculated_num_obese
# 1            High school graduate                 247.0
# 2               $50,000 - $74,999               18018.0
# 7           Less than high school                  77.0
# 9                         25 - 34                 210.0
# 12  American Indian/Alaska Native                2354.0

# %%
no_leisure_df = data_df[data_df['Question'] == 'Percent of adults who engage in no leisure-time physical activity']
no_leisure_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16549 entries, 0 to 88628
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   YearEnd                  16549 non-null  int64
#  1   LocationAbbr             16549 non-null  object
#  2   Question                 16549 non-null  object
#  3   Data_Value               14984 non-null  float64
#  4   Sample_Size              14984 non-null  float64
#  5   Race/Ethnicity           4728 non-null   object
#  6   Education                2364 non-null   object
#  7   Gender                   1182 non-null   object
#  8   StratificationCategory1  16548 non-null  object
#  9   Stratification1          16548 non-null  object
#  10  calculated_num_obese     14984 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 1.5+ MB

# %%
no_fruit_df = data_df[data_df['Question'] == 'Percent of adults who report consuming fruit less than one time daily']
no_fruit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4565 entries, 22 to 88627
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   YearEnd                  4565 non-null   int64
#  1   LocationAbbr             4565 non-null   object
#  2   Question                 4565 non-null   object
#  3   Data_Value               4080 non-null   float64
#  4   Sample_Size              4080 non-null   float64
#  5   Race/Ethnicity           1304 non-null   object
#  6   Education                652 non-null    object
#  7   Gender                   326 non-null    object
#  8   StratificationCategory1  4564 non-null   object
#  9   Stratification1          4564 non-null   object
#  10  calculated_num_obese     4080 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 428.0+ KB

# %%
no_vegetables_df = data_df[data_df['Question'] == 'Percent of adults who report consuming vegetables less than one time daily']
no_vegetables_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4565 entries, 75 to 88624
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   YearEnd                  4565 non-null   int64
#  1   LocationAbbr             4565 non-null   object
#  2   Question                 4565 non-null   object
#  3   Data_Value               4075 non-null   float64
#  4   Sample_Size              4075 non-null   float64
#  5   Race/Ethnicity           1304 non-null   object
#  6   Education                652 non-null    object
#  7   Gender                   326 non-null    object
#  8   StratificationCategory1  4564 non-null   object
#  9   Stratification1          4564 non-null   object
#  10  calculated_num_obese     4075 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 428.0+ KB

# %%
alabama_df = data_df[data_df['LocationAbbr'] == 'AL']
alabama_df.head()
# Out:
#      YearEnd LocationAbbr                                           Question  \
# 9       2011           AL  Percent of adults aged 18 years and older who ...
# 48      2016           AL  Percent of adults aged 18 years and older who ...
# 119     2018           AL  Percent of adults aged 18 years and older who ...
# 236     2020           AL  Percent of adults aged 18 years and older who ...
# 305     2016           AL  Percent of adults aged 18 years and older who ...
#
#      Data_Value  Sample_Size             Race/Ethnicity Education Gender  \
# 9          35.2        598.0                        NaN       NaN    NaN
# 48         35.3       1402.0                        NaN       NaN    NaN
# 119        31.9        719.0                        NaN       NaN    NaN
# 236        37.7       2089.0                        NaN       NaN   Male
# 305         NaN          NaN  Hawaiian/Pacific Islander       NaN    NaN
#
#     StratificationCategory1            Stratification1  calculated_num_obese
# 9               Age (years)                    25 - 34                 210.0
# 48              Age (years)                    55 - 64                 495.0
# 119             Age (years)                    35 - 44                 229.0
# 236                  Gender                       Male                 788.0
# 305          Race/Ethnicity  Hawaiian/Pacific Islander                   NaN

# %%
race_state_df = data_df.loc[:,['YearEnd','LocationAbbr','Question','Data_Value','Sample_Size','Race/Ethnicity']]
race_state_df = race_state_df[race_state_df['Race/Ethnicity'].notna()]
race_state_df = race_state_df[race_state_df['Data_Value'].notna()]
race_state_df = race_state_df[race_state_df['YearEnd']==2021]
veggies_race_state_df = race_state_df[race_state_df['Question']=='Percent of adults who report consuming vegetables less than one time daily']
fruit_race_state_df = race_state_df[race_state_df['Question']=='Percent of adults who report consuming fruit less than one time daily']
race_state_df = pd.concat([veggies_race_state_df,fruit_race_state_df], axis=0)

race_state_df
# Out:
#        YearEnd LocationAbbr  \
# 80983     2021           OH
# 80990     2021           WV
# 81011     2021           AL
# 81018     2021           GU
# 81044     2021           IA
# ...        ...          ...
# 88532     2021           PA
# 88543     2021           NY
# 88553     2021           VA
# 88572     2021           ME
# 88605     2021           ID
#
#                                                 Question  Data_Value  \
# 80983  Percent of adults who report consuming vegetab...        25.0
# 80990  Percent of adults who report consuming vegetab...        18.8
# 81011  Percent of adults who report consuming vegetab...        27.1
# 81018  Percent of adults who report consuming vegetab...        32.0
# 81044  Percent of adults who report consuming vegetab...        33.9
# ...                                                  ...         ...
# 88532  Percent of adults who report consuming fruit l...        42.5
# 88543  Percent of adults who report consuming fruit l...        32.8
# 88553  Percent of adults who report consuming fruit l...        40.9
# 88572  Percent of adults who report consuming fruit l...        32.8
# 88605  Percent of adults who report consuming fruit l...        41.8
#
#        Sample_Size             Race/Ethnicity
# 80983        240.0            2 or more races
# 80990       5576.0         Non-Hispanic White
# 81011       1031.0         Non-Hispanic Black
# 81018        513.0  Hawaiian/Pacific Islander
# 81044        158.0         Non-Hispanic Black
# ...            ...                        ...
# 88532        177.0                      Asian
# 88543        847.0                      Asian
# 88553        170.0            2 or more races
# 88572         52.0                      Other
# 88605        446.0                   Hispanic
#
# [586 rows x 6 columns]

# %%
gender_data_df = data_df.loc[:,['YearEnd','LocationAbbr','Question','Data_Value','Sample_Size','StratificationCategory1','Stratification1']]

gender_data_df = gender_data_df[gender_data_df['YearEnd']==2021]
gender_data_df = gender_data_df[gender_data_df['StratificationCategory1']=='Gender']
gender_data_df = gender_data_df[gender_data_df['Question']=='Percent of adults aged 18 years and older who have obesity']

gender_data_df
# Out:
#        YearEnd LocationAbbr  \
# 80930     2021           VT
# 80944     2021           ND
# 80991     2021           DC
# 81064     2021           NE
# 81137     2021           MD
# ...        ...          ...
# 88339     2021           RI
# 88415     2021           OR
# 88469     2021           PA
# 88488     2021           VI
# 88579     2021           MT
#
#                                                 Question  Data_Value  \
# 80930  Percent of adults aged 18 years and older who ...        29.0
# 80944  Percent of adults aged 18 years and older who ...        37.1
# 80991  Percent of adults aged 18 years and older who ...        28.6
# 81064  Percent of adults aged 18 years and older who ...        36.8
# 81137  Percent of adults aged 18 years and older who ...        33.3
# ...                                                  ...         ...
# 88339  Percent of adults aged 18 years and older who ...        29.2
# 88415  Percent of adults aged 18 years and older who ...        31.1
# 88469  Percent of adults aged 18 years and older who ...        32.6
# 88488  Percent of adults aged 18 years and older who ...        44.5
# 88579  Percent of adults aged 18 years and older who ...        31.7
#
#        Sample_Size StratificationCategory1 Stratification1
# 80930       3080.0                  Gender          Female
# 80944       2871.0                  Gender            Male
# 80991       1497.0                  Gender          Female
# 81064       6474.0                  Gender            Male
# 81137       6509.0                  Gender            Male
# ...            ...                     ...             ...
# 88339       2617.0                  Gender          Female
# 88415       2406.0                  Gender          Female
# 88469       2891.0                  Gender          Female
# 88488        654.0                  Gender          Female
# 88579       3046.0                  Gender            Male
#
# [110 rows x 7 columns]

# %%
vermont_data_df = gender_data_df[gender_data_df['LocationAbbr']=='VT']
vermont_data_df
# Out:
#        YearEnd LocationAbbr  \
# 80930     2021           VT
# 88189     2021           VT
#
#                                                 Question  Data_Value  \
# 80930  Percent of adults aged 18 years and older who ...        29.0
# 88189  Percent of adults aged 18 years and older who ...        29.1
#
#        Sample_Size StratificationCategory1 Stratification1
# 80930       3080.0                  Gender          Female
# 88189       2832.0                  Gender            Male
