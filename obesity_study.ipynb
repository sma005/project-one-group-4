# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import string
from datetime import date 
from scipy.stats import linregress

#Notes: https://data.cdc.gov/Nutrition-Physical-Activity-and-Obesity/Nutrition-Physical-Activity-and-Obesity-Behavioral/hn4x-zwk7

# %%
#Import the API Key
from api_key import api_key

#import data
url = "https://data.cdc.gov/resource/hn4x-zwk7.json"

response = requests.get(url)
data = response.json()

data
# Out:
# [{'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '44.8',
#   'data_value_alt': '44.8',
#   'low_confidence_limit': '37.0',
#   'high_confidence_limit': '52.9',
#   'sample_size': '223.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '24.7',
#   'data_value_alt': '24.7',
#   'low_confidence_limit': '18.3',
#   'high_confidence_limit': '32.6',
#   'sample_size': '219.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '19.3',
#   'data_value_alt': '19.3',
#   'low_confidence_limit': '14.4',
#   'high_confidence_limit': '25.4',
#   'sample_size': '254.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '28.5',
#   'data_value_alt': '28.5',
#   'low_confidence_limit': '21.6',
#   'high_confidence_limit': '36.5',
#   'sample_size': '232.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '25.4',
#   'data_value_alt': '25.4',
#   'low_confidence_limit': '19.2',
#   'high_confidence_limit': '32.8',
#   'sample_size': '232.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '23.3',
#   'data_value_alt': '23.3',
#   'low_confidence_limit': '19.2',
#   'high_confidence_limit': '28.0',
#   'sample_size': '475.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '21.1',
#   'data_value_alt': '21.1',
#   'low_confidence_limit': '17.1',
#   'high_confidence_limit': '25.8',
#   'sample_size': '433.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '49.4',
#   'data_value_alt': '49.4',
#   'low_confidence_limit': '43.7',
#   'high_confidence_limit': '55.1',
#   'sample_size': '419.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '46.6',
#   'data_value_alt': '46.6',
#   'low_confidence_limit': '41.0',
#   'high_confidence_limit': '52.2',
#   'sample_size': '433.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '20.3',
#   'data_value_alt': '20.3',
#   'low_confidence_limit': '15.8',
#   'high_confidence_limit': '25.7',
#   'sample_size': '410.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '16.7',
#   'data_value_alt': '16.7',
#   'low_confidence_limit': '12.9',
#   'high_confidence_limit': '21.3',
#   'sample_size': '499.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '22.4',
#   'data_value_alt': '22.4',
#   'low_confidence_limit': '18.5',
#   'high_confidence_limit': '26.8',
#   'sample_size': '553.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '44.5',
#   'data_value_alt': '44.5',
#   'low_confidence_limit': '39.2',
#   'high_confidence_limit': '49.8',
#   'sample_size': '507.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '45.8',
#   'data_value_alt': '45.8',
#   'low_confidence_limit': '40.6',
#   'high_confidence_limit': '51.1',
#   'sample_size': '521.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '31.8',
#   'data_value_alt': '31.8',
#   'low_confidence_limit': '27.2',
#   'high_confidence_limit': '36.8',
#   'sample_size': '521.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '35.6',
#   'data_value_alt': '35.6',
#   'low_confidence_limit': '31.1',
#   'high_confidence_limit': '40.3',
#   'sample_size': '638.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '49.2',
#   'data_value_alt': '49.2',
#   'low_confidence_limit': '44.3',
#   'high_confidence_limit': '54.0',
#   'sample_size': '577.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '46.4',
#   'data_value_alt': '46.4',
#   'low_confidence_limit': '41.6',
#   'high_confidence_limit': '51.2',
#   'sample_size': '594.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '33.8',
#   'data_value_alt': '33.8',
#   'low_confidence_limit': '29.4',
#   'high_confidence_limit': '38.6',
#   'sample_size': '594.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '19.5',
#   'data_value_alt': '19.5',
#   'low_confidence_limit': '15.7',
#   'high_confidence_limit': '23.9',
#   'sample_size': '570.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '32.7',
#   'data_value_alt': '32.7',
#   'low_confidence_limit': '28.9',
#   'high_confidence_limit': '36.7',
#   'sample_size': '826.0',
#   'age_years': '55 - 64',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '55 - 64',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR5564'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '39.1',
#   'data_value_alt': '39.1',
#   'low_confidence_limit': '35.2',
#   'high_confidence_limit': '43.2',
#   'sample_size': '900.0',
#   'age_years': '55 - 64',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '55 - 64',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR5564'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '48.4',
#   'data_value_alt': '48.4',
#   'low_confidence_limit': '44.1',
#   'high_confidence_limit': '52.8',
#   'sample_size': '809.0',
#   'age_years': '55 - 64',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '55 - 64',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR5564'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '21.2',
#   'data_value_alt': '21.2',
#   'low_confidence_limit': '17.8',
#   'high_confidence_limit': '25.0',
#   'sample_size': '811.0',
#   'age_years': '55 - 64',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '55 - 64',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR5564'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '44.4',
#   'data_value_alt': '44.4',
#   'low_confidence_limit': '40.2',
#   'high_confidence_limit': '48.7',
#   'sample_size': '826.0',
#   'age_years': '55 - 64',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '55 - 64',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR5564'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '21.7',
#   'data_value_alt': '21.7',
#   'low_confidence_limit': '19.1',
#   'high_confidence_limit': '24.5',
#   'sample_size': '1607.0',
#   'age_years': '65 or older',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '65 or older',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR65PLUS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '41.3',
#   'data_value_alt': '41.3',
#   'low_confidence_limit': '38.3',
#   'high_confidence_limit': '44.4',
#   'sample_size': '1758.0',
#   'age_years': '65 or older',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '65 or older',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR65PLUS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '41.1',
#   'data_value_alt': '41.1',
#   'low_confidence_limit': '38.0',
#   'high_confidence_limit': '44.3',
#   'sample_size': '1642.0',
#   'age_years': '65 or older',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '65 or older',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR65PLUS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '39.4',
#   'data_value_alt': '39.4',
#   'low_confidence_limit': '36.3',
#   'high_confidence_limit': '42.6',
#   'sample_size': '1641.0',
#   'age_years': '65 or older',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '65 or older',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR65PLUS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '30.9',
#   'data_value_alt': '30.9',
#   'low_confidence_limit': '28.1',
#   'high_confidence_limit': '33.8',
#   'sample_size': '1641.0',
#   'age_years': '65 or older',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '65 or older',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR65PLUS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '40.5',
#   'data_value_alt': '40.5',
#   'low_confidence_limit': '37.5',
#   'high_confidence_limit': '43.5',
#   'sample_size': '1566.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '34.2',
#   'data_value_alt': '34.2',
#   'low_confidence_limit': '31.4',
#   'high_confidence_limit': '37.2',
#   'sample_size': '1553.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '15.5',
#   'data_value_alt': '15.5',
#   'low_confidence_limit': '13.3',
#   'high_confidence_limit': '17.9',
#   'sample_size': '1555.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '34.3',
#   'data_value_alt': '34.3',
#   'low_confidence_limit': '31.5',
#   'high_confidence_limit': '37.3',
#   'sample_size': '1553.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '19.8',
#   'data_value_alt': '19.8',
#   'low_confidence_limit': '17.7',
#   'high_confidence_limit': '22.0',
#   'sample_size': '1671.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '42.6',
#   'data_value_alt': '42.6',
#   'low_confidence_limit': '39.1',
#   'high_confidence_limit': '46.1',
#   'sample_size': '1194.0',
#   'education': 'Some college or technical school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Some college or technical school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOTEC'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '15.0',
#   'data_value_alt': '15.0',
#   'low_confidence_limit': '12.6',
#   'high_confidence_limit': '17.8',
#   'sample_size': '1149.0',
#   'education': 'Some college or technical school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Some college or technical school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOTEC'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '31.6',
#   'data_value_alt': '31.6',
#   'low_confidence_limit': '28.4',
#   'high_confidence_limit': '35.0',
#   'sample_size': '1194.0',
#   'education': 'Some college or technical school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Some college or technical school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOTEC'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '47.6',
#   'data_value_alt': '47.6',
#   'low_confidence_limit': '44.0',
#   'high_confidence_limit': '51.2',
#   'sample_size': '1177.0',
#   'education': 'Some college or technical school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Some college or technical school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOTEC'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '27.9',
#   'data_value_alt': '27.9',
#   'low_confidence_limit': '25.1',
#   'high_confidence_limit': '30.9',
#   'sample_size': '1289.0',
#   'education': 'Some college or technical school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Some college or technical school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOTEC'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '27.8',
#   'data_value_alt': '27.8',
#   'low_confidence_limit': '22.0',
#   'high_confidence_limit': '34.6',
#   'sample_size': '305.0',
#   'education': 'Less than high school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Less than high school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '46.9',
#   'data_value_alt': '46.9',
#   'low_confidence_limit': '40.4',
#   'high_confidence_limit': '53.5',
#   'sample_size': '356.0',
#   'education': 'Less than high school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Less than high school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '40.5',
#   'data_value_alt': '40.5',
#   'low_confidence_limit': '33.9',
#   'high_confidence_limit': '47.5',
#   'sample_size': '328.0',
#   'education': 'Less than high school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Less than high school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '33.1',
#   'data_value_alt': '33.1',
#   'low_confidence_limit': '27.1',
#   'high_confidence_limit': '39.7',
#   'sample_size': '328.0',
#   'education': 'Less than high school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Less than high school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '44.4',
#   'data_value_alt': '44.4',
#   'low_confidence_limit': '37.5',
#   'high_confidence_limit': '51.7',
#   'sample_size': '311.0',
#   'education': 'Less than high school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Less than high school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '37.4',
#   'data_value_alt': '37.4',
#   'low_confidence_limit': '34.1',
#   'high_confidence_limit': '40.8',
#   'sample_size': '1245.0',
#   'education': 'High school graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'High school graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHSGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '49.3',
#   'data_value_alt': '49.3',
#   'low_confidence_limit': '45.5',
#   'high_confidence_limit': '53.1',
#   'sample_size': '1113.0',
#   'education': 'High school graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'High school graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHSGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '30.1',
#   'data_value_alt': '30.1',
#   'low_confidence_limit': '26.8',
#   'high_confidence_limit': '33.7',
#   'sample_size': '1165.0',
#   'education': 'High school graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'High school graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHSGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '41.1',
#   'data_value_alt': '41.1',
#   'low_confidence_limit': '37.5',
#   'high_confidence_limit': '44.8',
#   'sample_size': '1165.0',
#   'education': 'High school graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'High school graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHSGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
# ...
#   'data_value_alt': '21.3',
#   'low_confidence_limit': '15.3',
#   'high_confidence_limit': '28.8',
#   'sample_size': '210.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '17.5',
#   'data_value_alt': '17.5',
#   'low_confidence_limit': '12.0',
#   'high_confidence_limit': '24.9',
#   'sample_size': '180.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '24.7',
#   'data_value_alt': '24.7',
#   'low_confidence_limit': '19.4',
#   'high_confidence_limit': '30.8',
#   'sample_size': '372.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '31.2',
#   'data_value_alt': '31.2',
#   'low_confidence_limit': '25.3',
#   'high_confidence_limit': '37.7',
#   'sample_size': '329.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '31.4',
#   'data_value_alt': '31.4',
#   'low_confidence_limit': '25.5',
#   'high_confidence_limit': '37.9',
#   'sample_size': '329.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '24.1',
#   'data_value_alt': '24.1',
#   'low_confidence_limit': '19.1',
#   'high_confidence_limit': '30.1',
#   'sample_size': '322.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '39.5',
#   'data_value_alt': '39.5',
#   'low_confidence_limit': '33.0',
#   'high_confidence_limit': '46.3',
#   'sample_size': '330.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '22.3',
#   'data_value_alt': '22.3',
#   'low_confidence_limit': '17.9',
#   'high_confidence_limit': '27.4',
#   'sample_size': '487.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '38.3',
#   'data_value_alt': '38.3',
#   'low_confidence_limit': '32.4',
#   'high_confidence_limit': '44.6',
#   'sample_size': '419.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '20.4',
#   'data_value_alt': '20.4',
#   'low_confidence_limit': '15.6',
#   'high_confidence_limit': '26.1',
#   'sample_size': '397.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '39.8',
#   'data_value_alt': '39.8',
#   'low_confidence_limit': '33.8',
#   'high_confidence_limit': '46.2',
#   'sample_size': '412.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '35.5',
#   'data_value_alt': '35.5',
#   'low_confidence_limit': '29.6',
#   'high_confidence_limit': '41.7',
#   'sample_size': '419.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '45.5',
#   'data_value_alt': '45.5',
#   'low_confidence_limit': '39.8',
#   'high_confidence_limit': '51.4',
#   'sample_size': '479.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '25.6',
#   'data_value_alt': '25.6',
#   'low_confidence_limit': '21.1',
#   'high_confidence_limit': '30.6',
#   'sample_size': '562.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '33.9',
#   'data_value_alt': '33.9',
#   'low_confidence_limit': '28.8',
#   'high_confidence_limit': '39.3',
#   'sample_size': '489.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '39.6',
#   'data_value_alt': '39.6',
#   'low_confidence_limit': '34.2',
#   'high_confidence_limit': '45.2',
#   'sample_size': '489.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '15.2',
#   'data_value_alt': '15.2',
#   'low_confidence_limit': '11.4',
#   'high_confidence_limit': '20.0',
#   'sample_size': '465.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'}]

# %%
# Convert the cities weather data into a Pandas DataFrame
data_df = pd.DataFrame(data)

data_df = obesity_df[['yearend','locationabbr','topic','question','data_value','data_value_alt','low_confidence_limit','high_confidence_limit','sample_size','age_years']]

data_df['data_value'] = data_df.data_value.astype(float)
data_df['data_value_alt'] = data_df.data_value_alt.astype(float)
data_df['low_confidence_limit'] = data_df.low_confidence_limit.astype(float)
data_df['high_confidence_limit'] = data_df.high_confidence_limit.astype(float)
data_df['sample_size'] = data_df.sample_size.astype(float)

data_df.info()
# Show Record Count
data_df
#data_df.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   yearend                1000 non-null   object
#  1   locationabbr           1000 non-null   object
#  2   topic                  1000 non-null   object
#  3   question               1000 non-null   object
#  4   data_value             930 non-null    float64
#  5   data_value_alt         930 non-null    float64
#  6   low_confidence_limit   930 non-null    float64
#  7   high_confidence_limit  930 non-null    float64
#  8   sample_size            930 non-null    float64
#  9   age_years              230 non-null    object
# dtypes: float64(5), object(5)
# memory usage: 78.2+ KB
#     yearend locationabbr                             topic  \
# 0      2021           AL           Obesity / Weight Status
# 1      2021           AL  Fruits and Vegetables - Behavior
# 2      2021           AL           Obesity / Weight Status
# 3      2021           AL  Fruits and Vegetables - Behavior
# 4      2021           AL      Physical Activity - Behavior
# ..      ...          ...                               ...
# 995    2021           DE  Fruits and Vegetables - Behavior
# 996    2021           DE  Fruits and Vegetables - Behavior
# 997    2021           DE           Obesity / Weight Status
# 998    2021           DE      Physical Activity - Behavior
# 999    2021           DE           Obesity / Weight Status
#
#                                               question  data_value  \
# 0    Percent of adults aged 18 years and older who ...        25.4
# 1    Percent of adults who report consuming fruit l...        44.8
# 2    Percent of adults aged 18 years and older who ...        28.5
# 3    Percent of adults who report consuming vegetab...        24.7
# 4    Percent of adults who engage in no leisure-tim...        19.3
# ..                                                 ...         ...
# 995  Percent of adults who report consuming vegetab...        15.2
# 996  Percent of adults who report consuming fruit l...        45.5
# 997  Percent of adults aged 18 years and older who ...        33.9
# 998  Percent of adults who engage in no leisure-tim...        25.6
# 999  Percent of adults aged 18 years and older who ...        39.6
#
#      data_value_alt  low_confidence_limit  high_confidence_limit  sample_size  \
# 0              25.4                  19.2                   32.8        232.0
# 1              44.8                  37.0                   52.9        223.0
# 2              28.5                  21.6                   36.5        232.0
# 3              24.7                  18.3                   32.6        219.0
# 4              19.3                  14.4                   25.4        254.0
# ..              ...                   ...                    ...          ...
# 995            15.2                  11.4                   20.0        465.0
# 996            45.5                  39.8                   51.4        479.0
# 997            33.9                  28.8                   39.3        489.0
# 998            25.6                  21.1                   30.6        562.0
# 999            39.6                  34.2                   45.2        489.0
#
#     age_years
# 0     18 - 24
# 1     18 - 24
# 2     18 - 24
# 3     18 - 24
# 4     18 - 24
# ..        ...
# 995   45 - 54
# 996   45 - 54
# 997   45 - 54
# 998   45 - 54
# 999   45 - 54
#
# [1000 rows x 10 columns]

# %%
num_of_participants = data_df['sample_size'].sum()
num_of_participants
# Out:
# 1400392.0

# %%
#These are the questions this dataset answers
list_of_questions = data_df['question'].unique()
print(sorted(list_of_questions))
# Out:
# ['Percent of adults aged 18 years and older who have an overweight classification', 'Percent of adults aged 18 years and older who have obesity', 'Percent of adults who engage in no leisure-time physical activity', 'Percent of adults who report consuming fruit less than one time daily', 'Percent of adults who report consuming vegetables less than one time daily']

# %%
#These are the age groups
age_groups = data_df['age_years'].unique()
print(age_groups)
# Out:
# ['18 - 24' '25 - 34' '35 - 44' '45 - 54' '55 - 64' '65 or older' nan]

# %%
overweight_df = data_df[data_df['question'] == 'Percent of adults aged 18 years and older who have an overweight classification']
overweight_df
# Out:
#     yearend locationabbr                    topic  \
# 2      2021           AL  Obesity / Weight Status
# 5      2021           AL  Obesity / Weight Status
# 11     2021           AL  Obesity / Weight Status
# 18     2021           AL  Obesity / Weight Status
# 20     2021           AL  Obesity / Weight Status
# ..      ...          ...                      ...
# 979    2021           CT  Obesity / Weight Status
# 981    2021           DE  Obesity / Weight Status
# 987    2021           DE  Obesity / Weight Status
# 990    2021           DE  Obesity / Weight Status
# 997    2021           DE  Obesity / Weight Status
#
#                                               question data_value  \
# 2    Percent of adults aged 18 years and older who ...       28.5
# 5    Percent of adults aged 18 years and older who ...       21.1
# 11   Percent of adults aged 18 years and older who ...       31.8
# 18   Percent of adults aged 18 years and older who ...       33.8
# 20   Percent of adults aged 18 years and older who ...       32.7
# ..                                                 ...        ...
# 979  Percent of adults aged 18 years and older who ...       35.6
# 981  Percent of adults aged 18 years and older who ...       22.5
# 987  Percent of adults aged 18 years and older who ...       31.2
# 990  Percent of adults aged 18 years and older who ...       35.5
# 997  Percent of adults aged 18 years and older who ...       33.9
#
#     data_value_alt low_confidence_limit high_confidence_limit sample_size  \
# 2             28.5                 21.6                  36.5       232.0
# 5             21.1                 17.1                  25.8       433.0
# 11            31.8                 27.2                  36.8       521.0
# 18            33.8                 29.4                  38.6       594.0
# 20            32.7                 28.9                  36.7       826.0
# ..             ...                  ...                   ...         ...
# 979           35.6                 33.9                  37.4      5161.0
# 981           22.5                 16.1                  30.6       180.0
# 987           31.2                 25.3                  37.7       329.0
# 990           35.5                 29.6                  41.7       419.0
# 997           33.9                 28.8                  39.3       489.0
#
#     age_years
# 2     18 - 24
# 5     25 - 34
# 11    35 - 44
# 18    45 - 54
# 20    55 - 64
# ..        ...
# 979       NaN
# 981   18 - 24
# 987   25 - 34
# 990   35 - 44
# 997   45 - 54
#
# [200 rows x 10 columns]

# %%
obese_df = data_df[data_df['question'] == 'Percent of adults aged 18 years and older who have obesity']
obese_df
# Out:
#     yearend locationabbr                    topic  \
# 0      2021           AL  Obesity / Weight Status
# 6      2021           AL  Obesity / Weight Status
# 13     2021           AL  Obesity / Weight Status
# 15     2021           AL  Obesity / Weight Status
# 21     2021           AL  Obesity / Weight Status
# ..      ...          ...                      ...
# 978    2021           CT  Obesity / Weight Status
# 983    2021           DE  Obesity / Weight Status
# 988    2021           DE  Obesity / Weight Status
# 994    2021           DE  Obesity / Weight Status
# 999    2021           DE  Obesity / Weight Status
#
#                                               question data_value  \
# 0    Percent of adults aged 18 years and older who ...       25.4
# 6    Percent of adults aged 18 years and older who ...       46.6
# 13   Percent of adults aged 18 years and older who ...       45.8
# 15   Percent of adults aged 18 years and older who ...       46.4
# 21   Percent of adults aged 18 years and older who ...       44.4
# ..                                                 ...        ...
# 978  Percent of adults aged 18 years and older who ...       28.8
# 983  Percent of adults aged 18 years and older who ...       17.5
# 988  Percent of adults aged 18 years and older who ...       31.4
# 994  Percent of adults aged 18 years and older who ...       38.3
# 999  Percent of adults aged 18 years and older who ...       39.6
#
#     data_value_alt low_confidence_limit high_confidence_limit sample_size  \
# 0             25.4                 19.2                  32.8       232.0
# 6             46.6                 41.0                  52.2       433.0
# 13            45.8                 40.6                  51.1       521.0
# 15            46.4                 41.6                  51.2       594.0
# 21            44.4                 40.2                  48.7       826.0
# ..             ...                  ...                   ...         ...
# 978           28.8                 27.1                  30.6      5161.0
# 983           17.5                 12.0                  24.9       180.0
# 988           31.4                 25.5                  37.9       329.0
# 994           38.3                 32.4                  44.6       419.0
# 999           39.6                 34.2                  45.2       489.0
#
#     age_years
# 0     18 - 24
# 6     25 - 34
# 13    35 - 44
# 15    45 - 54
# 21    55 - 64
# ..        ...
# 978       NaN
# 983   18 - 24
# 988   25 - 34
# 994   35 - 44
# 999   45 - 54
#
# [200 rows x 10 columns]

# %%
no_leisure_df = data_df[data_df['question'] == 'Percent of adults who engage in no leisure-time physical activity']
no_leisure_df
# Out:
#     yearend locationabbr                         topic  \
# 4      2021           AL  Physical Activity - Behavior
# 7      2021           AL  Physical Activity - Behavior
# 14     2021           AL  Physical Activity - Behavior
# 17     2021           AL  Physical Activity - Behavior
# 22     2021           AL  Physical Activity - Behavior
# ..      ...          ...                           ...
# 975    2021           CT  Physical Activity - Behavior
# 982    2021           DE  Physical Activity - Behavior
# 985    2021           DE  Physical Activity - Behavior
# 993    2021           DE  Physical Activity - Behavior
# 998    2021           DE  Physical Activity - Behavior
#
#                                               question data_value  \
# 4    Percent of adults who engage in no leisure-tim...       19.3
# 7    Percent of adults who engage in no leisure-tim...       23.3
# 14   Percent of adults who engage in no leisure-tim...       22.4
# 17   Percent of adults who engage in no leisure-tim...       35.6
# 22   Percent of adults who engage in no leisure-tim...       39.1
# ..                                                 ...        ...
# 975  Percent of adults who engage in no leisure-tim...       18.4
# 982  Percent of adults who engage in no leisure-tim...       21.3
# 985  Percent of adults who engage in no leisure-tim...       24.7
# 993  Percent of adults who engage in no leisure-tim...       22.3
# 998  Percent of adults who engage in no leisure-tim...       25.6
#
#     data_value_alt low_confidence_limit high_confidence_limit sample_size  \
# 4             19.3                 14.4                  25.4       254.0
# 7             23.3                 19.2                  28.0       475.0
# 14            22.4                 18.5                  26.8       553.0
# 17            35.6                 31.1                  40.3       638.0
# 22            39.1                 35.2                  43.2       900.0
# ..             ...                  ...                   ...         ...
# 975           18.4                 17.0                  19.9      5949.0
# 982           21.3                 15.3                  28.8       210.0
# 985           24.7                 19.4                  30.8       372.0
# 993           22.3                 17.9                  27.4       487.0
# 998           25.6                 21.1                  30.6       562.0
#
#     age_years
# 4     18 - 24
# 7     25 - 34
# 14    35 - 44
# 17    45 - 54
# 22    55 - 64
# ..        ...
# 975       NaN
# 982   18 - 24
# 985   25 - 34
# 993   35 - 44
# 998   45 - 54
#
# [200 rows x 10 columns]

# %%
no_fruit_df = data_df[data_df['question'] == 'Percent of adults who report consuming fruit less than one time daily']
no_fruit_df
# Out:
#     yearend locationabbr                             topic  \
# 1      2021           AL  Fruits and Vegetables - Behavior
# 9      2021           AL  Fruits and Vegetables - Behavior
# 10     2021           AL  Fruits and Vegetables - Behavior
# 19     2021           AL  Fruits and Vegetables - Behavior
# 23     2021           AL  Fruits and Vegetables - Behavior
# ..      ...          ...                               ...
# 977    2021           CT  Fruits and Vegetables - Behavior
# 984    2021           DE  Fruits and Vegetables - Behavior
# 989    2021           DE  Fruits and Vegetables - Behavior
# 992    2021           DE  Fruits and Vegetables - Behavior
# 996    2021           DE  Fruits and Vegetables - Behavior
#
#                                               question data_value  \
# 1    Percent of adults who report consuming fruit l...       44.8
# 9    Percent of adults who report consuming fruit l...       49.4
# 10   Percent of adults who report consuming fruit l...       44.5
# 19   Percent of adults who report consuming fruit l...       49.2
# 23   Percent of adults who report consuming fruit l...       48.4
# ..                                                 ...        ...
# 977  Percent of adults who report consuming fruit l...       35.7
# 984  Percent of adults who report consuming fruit l...       44.2
# 989  Percent of adults who report consuming fruit l...       39.5
# 992  Percent of adults who report consuming fruit l...       39.8
# 996  Percent of adults who report consuming fruit l...       45.5
#
#     data_value_alt low_confidence_limit high_confidence_limit sample_size  \
# 1             44.8                 37.0                  52.9       223.0
# 9             49.4                 43.7                  55.1       419.0
# 10            44.5                 39.2                  49.8       507.0
# 19            49.2                 44.3                  54.0       577.0
# 23            48.4                 44.1                  52.8       809.0
# ..             ...                  ...                   ...         ...
# 977           35.7                 33.8                  37.6      5113.0
# 984           44.2                 35.2                  53.6       175.0
# 989           39.5                 33.0                  46.3       330.0
# 992           39.8                 33.8                  46.2       412.0
# 996           45.5                 39.8                  51.4       479.0
#
#     age_years
# 1     18 - 24
# 9     25 - 34
# 10    35 - 44
# 19    45 - 54
# 23    55 - 64
# ..        ...
# 977       NaN
# 984   18 - 24
# 989   25 - 34
# 992   35 - 44
# 996   45 - 54
#
# [200 rows x 10 columns]

# %%
no_vegetables_df = data_df[data_df['question'] == 'Percent of adults who report consuming vegetables less than one time daily']
no_vegetables_df
# Out:
#     yearend locationabbr                             topic  \
# 3      2021           AL  Fruits and Vegetables - Behavior
# 8      2021           AL  Fruits and Vegetables - Behavior
# 12     2021           AL  Fruits and Vegetables - Behavior
# 16     2021           AL  Fruits and Vegetables - Behavior
# 24     2021           AL  Fruits and Vegetables - Behavior
# ..      ...          ...                               ...
# 976    2021           CT  Fruits and Vegetables - Behavior
# 980    2021           DE  Fruits and Vegetables - Behavior
# 986    2021           DE  Fruits and Vegetables - Behavior
# 991    2021           DE  Fruits and Vegetables - Behavior
# 995    2021           DE  Fruits and Vegetables - Behavior
#
#                                               question data_value  \
# 3    Percent of adults who report consuming vegetab...       24.7
# 8    Percent of adults who report consuming vegetab...       20.3
# 12   Percent of adults who report consuming vegetab...       16.7
# 16   Percent of adults who report consuming vegetab...       19.5
# 24   Percent of adults who report consuming vegetab...       21.2
# ..                                                 ...        ...
# 976  Percent of adults who report consuming vegetab...       16.2
# 980  Percent of adults who report consuming vegetab...       35.9
# 986  Percent of adults who report consuming vegetab...       24.1
# 991  Percent of adults who report consuming vegetab...       20.4
# 995  Percent of adults who report consuming vegetab...       15.2
#
#     data_value_alt low_confidence_limit high_confidence_limit sample_size  \
# 3             24.7                 18.3                  32.6       219.0
# 8             20.3                 15.8                  25.7       410.0
# 12            16.7                 12.9                  21.3       499.0
# 16            19.5                 15.7                  23.9       570.0
# 24            21.2                 17.8                  25.0       811.0
# ..             ...                  ...                   ...         ...
# 976           16.2                 14.6                  17.9      4932.0
# 980           35.9                 27.3                  45.5       167.0
# 986           24.1                 19.1                  30.1       322.0
# 991           20.4                 15.6                  26.1       397.0
# 995           15.2                 11.4                  20.0       465.0
#
#     age_years
# 3     18 - 24
# 8     25 - 34
# 12    35 - 44
# 16    45 - 54
# 24    55 - 64
# ..        ...
# 976       NaN
# 980   18 - 24
# 986   25 - 34
# 991   35 - 44
# 995   45 - 54
#
# [200 rows x 10 columns]

# %%
alabama_df = data_df[data_df['locationabbr'] == 'AL']
alabama_df
# Out:
#     yearend locationabbr                             topic  \
# 0      2021           AL           Obesity / Weight Status
# 1      2021           AL  Fruits and Vegetables - Behavior
# 2      2021           AL           Obesity / Weight Status
# 3      2021           AL  Fruits and Vegetables - Behavior
# 4      2021           AL      Physical Activity - Behavior
# ..      ...          ...                               ...
# 135    2021           AL  Fruits and Vegetables - Behavior
# 136    2021           AL           Obesity / Weight Status
# 137    2021           AL  Fruits and Vegetables - Behavior
# 138    2021           AL           Obesity / Weight Status
# 139    2021           AL      Physical Activity - Behavior
#
#                                               question  data_value  \
# 0    Percent of adults aged 18 years and older who ...        25.4
# 1    Percent of adults who report consuming fruit l...        44.8
# 2    Percent of adults aged 18 years and older who ...        28.5
# 3    Percent of adults who report consuming vegetab...        24.7
# 4    Percent of adults who engage in no leisure-tim...        19.3
# ..                                                 ...         ...
# 135  Percent of adults who report consuming vegetab...        17.3
# 136  Percent of adults aged 18 years and older who ...        33.3
# 137  Percent of adults who report consuming fruit l...        49.6
# 138  Percent of adults aged 18 years and older who ...        36.8
# 139  Percent of adults who engage in no leisure-tim...        31.0
#
#      data_value_alt  low_confidence_limit  high_confidence_limit  sample_size  \
# 0              25.4                  19.2                   32.8        232.0
# 1              44.8                  37.0                   52.9        223.0
# 2              28.5                  21.6                   36.5        232.0
# 3              24.7                  18.3                   32.6        219.0
# 4              19.3                  14.4                   25.4        254.0
# ..              ...                   ...                    ...          ...
# 135            17.3                  15.5                   19.3       2805.0
# 136            33.3                  31.1                   35.5       2888.0
# 137            49.6                  47.2                   52.0       2854.0
# 138            36.8                  34.5                   39.1       2888.0
# 139            31.0                  29.0                   33.1       3080.0
#
#     age_years
# 0     18 - 24
# 1     18 - 24
# 2     18 - 24
# 3     18 - 24
# 4     18 - 24
# ..        ...
# 135       NaN
# 136       NaN
# 137       NaN
# 138       NaN
# 139       NaN
#
# [140 rows x 10 columns]

# %%
#https://www.geeksforgeeks.org/how-to-print-an-entire-pandas-dataframe-in-python/

# Permanently changes the pandas settings
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 0)
 
alabama_df
# Out:
#     yearend locationabbr                             topic  \
# 0    2021    AL           Obesity / Weight Status
# 1    2021    AL           Fruits and Vegetables - Behavior
# 2    2021    AL           Obesity / Weight Status
# 3    2021    AL           Fruits and Vegetables - Behavior
# 4    2021    AL           Physical Activity - Behavior
# 5    2021    AL           Obesity / Weight Status
# 6    2021    AL           Obesity / Weight Status
# 7    2021    AL           Physical Activity - Behavior
# 8    2021    AL           Fruits and Vegetables - Behavior
# 9    2021    AL           Fruits and Vegetables - Behavior
# 10   2021    AL           Fruits and Vegetables - Behavior
# 11   2021    AL           Obesity / Weight Status
# 12   2021    AL           Fruits and Vegetables - Behavior
# 13   2021    AL           Obesity / Weight Status
# 14   2021    AL           Physical Activity - Behavior
# 15   2021    AL           Obesity / Weight Status
# 16   2021    AL           Fruits and Vegetables - Behavior
# 17   2021    AL           Physical Activity - Behavior
# 18   2021    AL           Obesity / Weight Status
# 19   2021    AL           Fruits and Vegetables - Behavior
# 20   2021    AL           Obesity / Weight Status
# 21   2021    AL           Obesity / Weight Status
# 22   2021    AL           Physical Activity - Behavior
# 23   2021    AL           Fruits and Vegetables - Behavior
# 24   2021    AL           Fruits and Vegetables - Behavior
# 25   2021    AL           Obesity / Weight Status
# 26   2021    AL           Obesity / Weight Status
# 27   2021    AL           Fruits and Vegetables - Behavior
# 28   2021    AL           Fruits and Vegetables - Behavior
# 29   2021    AL           Physical Activity - Behavior
# 30   2021    AL           Physical Activity - Behavior
# 31   2021    AL           Obesity / Weight Status
# 32   2021    AL           Fruits and Vegetables - Behavior
# 33   2021    AL           Obesity / Weight Status
# 34   2021    AL           Fruits and Vegetables - Behavior
# 35   2021    AL           Physical Activity - Behavior
# 36   2021    AL           Obesity / Weight Status
# 37   2021    AL           Fruits and Vegetables - Behavior
# 38   2021    AL           Obesity / Weight Status
# 39   2021    AL           Fruits and Vegetables - Behavior
# 40   2021    AL           Fruits and Vegetables - Behavior
# 41   2021    AL           Obesity / Weight Status
# 42   2021    AL           Physical Activity - Behavior
# 43   2021    AL           Obesity / Weight Status
# 44   2021    AL           Fruits and Vegetables - Behavior
# 45   2021    AL           Physical Activity - Behavior
# 46   2021    AL           Fruits and Vegetables - Behavior
# 47   2021    AL           Fruits and Vegetables - Behavior
# 48   2021    AL           Obesity / Weight Status
# 49   2021    AL           Obesity / Weight Status
# 50   2021    AL           Physical Activity - Behavior
# 51   2021    AL           Fruits and Vegetables - Behavior
# 52   2021    AL           Obesity / Weight Status
# 53   2021    AL           Obesity / Weight Status
# 54   2021    AL           Fruits and Vegetables - Behavior
# 55   2021    AL           Obesity / Weight Status
# 56   2021    AL           Fruits and Vegetables - Behavior
# 57   2021    AL           Obesity / Weight Status
# 58   2021    AL           Fruits and Vegetables - Behavior
# 59   2021    AL           Physical Activity - Behavior
# 60   2021    AL           Fruits and Vegetables - Behavior
# 61   2021    AL           Physical Activity - Behavior
# 62   2021    AL           Obesity / Weight Status
# 63   2021    AL           Obesity / Weight Status
# 64   2021    AL           Fruits and Vegetables - Behavior
# 65   2021    AL           Obesity / Weight Status
# 66   2021    AL           Obesity / Weight Status
# 67   2021    AL           Fruits and Vegetables - Behavior
# 68   2021    AL           Physical Activity - Behavior
# 69   2021    AL           Fruits and Vegetables - Behavior
# 70   2021    AL           Obesity / Weight Status
# 71   2021    AL           Physical Activity - Behavior
# 72   2021    AL           Obesity / Weight Status
# 73   2021    AL           Fruits and Vegetables - Behavior
# 74   2021    AL           Fruits and Vegetables - Behavior
# 75   2021    AL           Physical Activity - Behavior
# 76   2021    AL           Obesity / Weight Status
# 77   2021    AL           Fruits and Vegetables - Behavior
# 78   2021    AL           Obesity / Weight Status
# 79   2021    AL           Fruits and Vegetables - Behavior
# 80   2021    AL           Fruits and Vegetables - Behavior
# 81   2021    AL           Physical Activity - Behavior
# 82   2021    AL           Obesity / Weight Status
# 83   2021    AL           Obesity / Weight Status
# 84   2021    AL           Fruits and Vegetables - Behavior
# 85   2021    AL           Fruits and Vegetables - Behavior
# 86   2021    AL           Obesity / Weight Status
# 87   2021    AL           Physical Activity - Behavior
# 88   2021    AL           Fruits and Vegetables - Behavior
# 89   2021    AL           Obesity / Weight Status
# 90   2021    AL           Fruits and Vegetables - Behavior
# 91   2021    AL           Physical Activity - Behavior
# 92   2021    AL           Fruits and Vegetables - Behavior
# 93   2021    AL           Obesity / Weight Status
# 94   2021    AL           Obesity / Weight Status
# 95   2021    AL           Obesity / Weight Status
# 96   2021    AL           Fruits and Vegetables - Behavior
# 97   2021    AL           Obesity / Weight Status
# 98   2021    AL           Fruits and Vegetables - Behavior
# 99   2021    AL           Physical Activity - Behavior
# 100  2021    AL           Fruits and Vegetables - Behavior
# 101  2021    AL           Physical Activity - Behavior
# 102  2021    AL           Fruits and Vegetables - Behavior
# 103  2021    AL           Obesity / Weight Status
# 104  2021    AL           Obesity / Weight Status
# 105  2021    AL           Fruits and Vegetables - Behavior
# 106  2021    AL           Fruits and Vegetables - Behavior
# 107  2021    AL           Physical Activity - Behavior
# 108  2021    AL           Obesity / Weight Status
# 109  2021    AL           Obesity / Weight Status
# 110  2021    AL           Obesity / Weight Status
# 111  2021    AL           Physical Activity - Behavior
# 112  2021    AL           Obesity / Weight Status
# 113  2021    AL           Fruits and Vegetables - Behavior
# 114  2021    AL           Fruits and Vegetables - Behavior
# 115  2021    AL           Fruits and Vegetables - Behavior
# 116  2021    AL           Obesity / Weight Status
# 117  2021    AL           Physical Activity - Behavior
# 118  2021    AL           Obesity / Weight Status
# 119  2021    AL           Fruits and Vegetables - Behavior
# 120  2021    AL           Obesity / Weight Status
# 121  2021    AL           Fruits and Vegetables - Behavior
# 122  2021    AL           Physical Activity - Behavior
# 123  2021    AL           Obesity / Weight Status
# 124  2021    AL           Fruits and Vegetables - Behavior
# 125  2021    AL           Obesity / Weight Status
# 126  2021    AL           Fruits and Vegetables - Behavior
# 127  2021    AL           Obesity / Weight Status
# 128  2021    AL           Fruits and Vegetables - Behavior
# 129  2021    AL           Physical Activity - Behavior
# 130  2021    AL           Obesity / Weight Status
# 131  2021    AL           Obesity / Weight Status
# 132  2021    AL           Fruits and Vegetables - Behavior
# 133  2021    AL           Physical Activity - Behavior
# 134  2021    AL           Fruits and Vegetables - Behavior
# 135  2021    AL           Fruits and Vegetables - Behavior
# 136  2021    AL           Obesity / Weight Status
# 137  2021    AL           Fruits and Vegetables - Behavior
# 138  2021    AL           Obesity / Weight Status
# 139  2021    AL           Physical Activity - Behavior
#
#                                                                             question  \
# 0    Percent of adults aged 18 years and older who have obesity
# 1    Percent of adults who report consuming fruit less than one time daily
# 2    Percent of adults aged 18 years and older who have an overweight classification
# 3    Percent of adults who report consuming vegetables less than one time daily
# 4    Percent of adults who engage in no leisure-time physical activity
# 5    Percent of adults aged 18 years and older who have an overweight classification
# 6    Percent of adults aged 18 years and older who have obesity
# 7    Percent of adults who engage in no leisure-time physical activity
# 8    Percent of adults who report consuming vegetables less than one time daily
# 9    Percent of adults who report consuming fruit less than one time daily
# 10   Percent of adults who report consuming fruit less than one time daily
# 11   Percent of adults aged 18 years and older who have an overweight classification
# 12   Percent of adults who report consuming vegetables less than one time daily
# 13   Percent of adults aged 18 years and older who have obesity
# 14   Percent of adults who engage in no leisure-time physical activity
# 15   Percent of adults aged 18 years and older who have obesity
# 16   Percent of adults who report consuming vegetables less than one time daily
# 17   Percent of adults who engage in no leisure-time physical activity
# 18   Percent of adults aged 18 years and older who have an overweight classification
# 19   Percent of adults who report consuming fruit less than one time daily
# 20   Percent of adults aged 18 years and older who have an overweight classification
# 21   Percent of adults aged 18 years and older who have obesity
# 22   Percent of adults who engage in no leisure-time physical activity
# 23   Percent of adults who report consuming fruit less than one time daily
# 24   Percent of adults who report consuming vegetables less than one time daily
# 25   Percent of adults aged 18 years and older who have obesity
# 26   Percent of adults aged 18 years and older who have an overweight classification
# 27   Percent of adults who report consuming fruit less than one time daily
# 28   Percent of adults who report consuming vegetables less than one time daily
# 29   Percent of adults who engage in no leisure-time physical activity
# 30   Percent of adults who engage in no leisure-time physical activity
# 31   Percent of adults aged 18 years and older who have obesity
# 32   Percent of adults who report consuming fruit less than one time daily
# 33   Percent of adults aged 18 years and older who have an overweight classification
# 34   Percent of adults who report consuming vegetables less than one time daily
# 35   Percent of adults who engage in no leisure-time physical activity
# 36   Percent of adults aged 18 years and older who have obesity
# 37   Percent of adults who report consuming fruit less than one time daily
# 38   Percent of adults aged 18 years and older who have an overweight classification
# 39   Percent of adults who report consuming vegetables less than one time daily
# 40   Percent of adults who report consuming fruit less than one time daily
# 41   Percent of adults aged 18 years and older who have an overweight classification
# 42   Percent of adults who engage in no leisure-time physical activity
# 43   Percent of adults aged 18 years and older who have obesity
# 44   Percent of adults who report consuming vegetables less than one time daily
# 45   Percent of adults who engage in no leisure-time physical activity
# 46   Percent of adults who report consuming vegetables less than one time daily
# 47   Percent of adults who report consuming fruit less than one time daily
# 48   Percent of adults aged 18 years and older who have obesity
# 49   Percent of adults aged 18 years and older who have an overweight classification
# 50   Percent of adults who engage in no leisure-time physical activity
# 51   Percent of adults who report consuming vegetables less than one time daily
# 52   Percent of adults aged 18 years and older who have obesity
# 53   Percent of adults aged 18 years and older who have an overweight classification
# 54   Percent of adults who report consuming fruit less than one time daily
# 55   Percent of adults aged 18 years and older who have an overweight classification
# 56   Percent of adults who report consuming fruit less than one time daily
# 57   Percent of adults aged 18 years and older who have obesity
# 58   Percent of adults who report consuming vegetables less than one time daily
# 59   Percent of adults who engage in no leisure-time physical activity
# 60   Percent of adults who report consuming fruit less than one time daily
# 61   Percent of adults who engage in no leisure-time physical activity
# 62   Percent of adults aged 18 years and older who have obesity
# 63   Percent of adults aged 18 years and older who have an overweight classification
# 64   Percent of adults who report consuming vegetables less than one time daily
# 65   Percent of adults aged 18 years and older who have obesity
# 66   Percent of adults aged 18 years and older who have an overweight classification
# 67   Percent of adults who report consuming fruit less than one time daily
# 68   Percent of adults who engage in no leisure-time physical activity
# 69   Percent of adults who report consuming vegetables less than one time daily
# 70   Percent of adults aged 18 years and older who have an overweight classification
# 71   Percent of adults who engage in no leisure-time physical activity
# 72   Percent of adults aged 18 years and older who have obesity
# 73   Percent of adults who report consuming vegetables less than one time daily
# 74   Percent of adults who report consuming fruit less than one time daily
# 75   Percent of adults who engage in no leisure-time physical activity
# 76   Percent of adults aged 18 years and older who have an overweight classification
# 77   Percent of adults who report consuming vegetables less than one time daily
# 78   Percent of adults aged 18 years and older who have obesity
# 79   Percent of adults who report consuming fruit less than one time daily
# 80   Percent of adults who report consuming fruit less than one time daily
# 81   Percent of adults who engage in no leisure-time physical activity
# 82   Percent of adults aged 18 years and older who have an overweight classification
# 83   Percent of adults aged 18 years and older who have obesity
# 84   Percent of adults who report consuming vegetables less than one time daily
# 85   Percent of adults who report consuming vegetables less than one time daily
# 86   Percent of adults aged 18 years and older who have obesity
# 87   Percent of adults who engage in no leisure-time physical activity
# 88   Percent of adults who report consuming fruit less than one time daily
# 89   Percent of adults aged 18 years and older who have an overweight classification
# 90   Percent of adults who report consuming vegetables less than one time daily
# 91   Percent of adults who engage in no leisure-time physical activity
# 92   Percent of adults who report consuming fruit less than one time daily
# 93   Percent of adults aged 18 years and older who have obesity
# 94   Percent of adults aged 18 years and older who have an overweight classification
# 95   Percent of adults aged 18 years and older who have an overweight classification
# 96   Percent of adults who report consuming vegetables less than one time daily
# 97   Percent of adults aged 18 years and older who have obesity
# 98   Percent of adults who report consuming fruit less than one time daily
# 99   Percent of adults who engage in no leisure-time physical activity
# 100  Percent of adults who report consuming fruit less than one time daily
# 101  Percent of adults who engage in no leisure-time physical activity
# 102  Percent of adults who report consuming vegetables less than one time daily
# 103  Percent of adults aged 18 years and older who have obesity
# 104  Percent of adults aged 18 years and older who have an overweight classification
# 105  Percent of adults who report consuming vegetables less than one time daily
# 106  Percent of adults who report consuming fruit less than one time daily
# 107  Percent of adults who engage in no leisure-time physical activity
# 108  Percent of adults aged 18 years and older who have an overweight classification
# 109  Percent of adults aged 18 years and older who have obesity
# 110  Percent of adults aged 18 years and older who have an overweight classification
# 111  Percent of adults who engage in no leisure-time physical activity
# 112  Percent of adults aged 18 years and older who have obesity
# 113  Percent of adults who report consuming vegetables less than one time daily
# 114  Percent of adults who report consuming fruit less than one time daily
# 115  Percent of adults who report consuming vegetables less than one time daily
# 116  Percent of adults aged 18 years and older who have an overweight classification
# 117  Percent of adults who engage in no leisure-time physical activity
# 118  Percent of adults aged 18 years and older who have obesity
# 119  Percent of adults who report consuming fruit less than one time daily
# 120  Percent of adults aged 18 years and older who have obesity
# 121  Percent of adults who report consuming fruit less than one time daily
# 122  Percent of adults who engage in no leisure-time physical activity
# 123  Percent of adults aged 18 years and older who have an overweight classification
# 124  Percent of adults who report consuming vegetables less than one time daily
# 125  Percent of adults aged 18 years and older who have obesity
# 126  Percent of adults who report consuming fruit less than one time daily
# 127  Percent of adults aged 18 years and older who have an overweight classification
# 128  Percent of adults who report consuming vegetables less than one time daily
# 129  Percent of adults who engage in no leisure-time physical activity
# 130  Percent of adults aged 18 years and older who have an overweight classification
# 131  Percent of adults aged 18 years and older who have obesity
# 132  Percent of adults who report consuming fruit less than one time daily
# 133  Percent of adults who engage in no leisure-time physical activity
# 134  Percent of adults who report consuming vegetables less than one time daily
# 135  Percent of adults who report consuming vegetables less than one time daily
# 136  Percent of adults aged 18 years and older who have an overweight classification
# 137  Percent of adults who report consuming fruit less than one time daily
# 138  Percent of adults aged 18 years and older who have obesity
# 139  Percent of adults who engage in no leisure-time physical activity
#
#      data_value  data_value_alt  low_confidence_limit  high_confidence_limit  \
# 0    25.4        25.4            19.2                  32.8
# 1    44.8        44.8            37.0                  52.9
# 2    28.5        28.5            21.6                  36.5
# 3    24.7        24.7            18.3                  32.6
# 4    19.3        19.3            14.4                  25.4
# 5    21.1        21.1            17.1                  25.8
# 6    46.6        46.6            41.0                  52.2
# 7    23.3        23.3            19.2                  28.0
# 8    20.3        20.3            15.8                  25.7
# 9    49.4        49.4            43.7                  55.1
# 10   44.5        44.5            39.2                  49.8
# 11   31.8        31.8            27.2                  36.8
# 12   16.7        16.7            12.9                  21.3
# 13   45.8        45.8            40.6                  51.1
# 14   22.4        22.4            18.5                  26.8
# 15   46.4        46.4            41.6                  51.2
# 16   19.5        19.5            15.7                  23.9
# 17   35.6        35.6            31.1                  40.3
# 18   33.8        33.8            29.4                  38.6
# 19   49.2        49.2            44.3                  54.0
# 20   32.7        32.7            28.9                  36.7
# 21   44.4        44.4            40.2                  48.7
# 22   39.1        39.1            35.2                  43.2
# 23   48.4        48.4            44.1                  52.8
# 24   21.2        21.2            17.8                  25.0
# 25   30.9        30.9            28.1                  33.8
# 26   39.4        39.4            36.3                  42.6
# 27   41.1        41.1            38.0                  44.3
# 28   21.7        21.7            19.1                  24.5
# 29   41.3        41.3            38.3                  44.4
# 30   19.8        19.8            17.7                  22.0
# 31   34.3        34.3            31.5                  37.3
# 32   40.5        40.5            37.5                  43.5
# 33   34.2        34.2            31.4                  37.2
# 34   15.5        15.5            13.3                  17.9
# 35   27.9        27.9            25.1                  30.9
# 36   42.6        42.6            39.1                  46.1
# 37   47.6        47.6            44.0                  51.2
# 38   31.6        31.6            28.4                  35.0
# 39   15.0        15.0            12.6                  17.8
# 40   44.4        44.4            37.5                  51.7
# 41   33.1        33.1            27.1                  39.7
# 42   46.9        46.9            40.4                  53.5
# 43   40.5        40.5            33.9                  47.5
# 44   27.8        27.8            22.0                  34.6
# 45   37.4        37.4            34.1                  40.8
# 46   27.3        27.3            23.9                  31.1
# 47   49.3        49.3            45.5                  53.1
# 48   41.1        41.1            37.5                  44.8
# 49   30.1        30.1            26.8                  33.7
# 50   35.7        35.7            33.4                  38.1
# 51   18.4        18.4            16.5                  20.6
# 52   41.6        41.6            39.0                  44.3
# 53   27.7        27.7            25.5                  30.1
# 54   44.8        44.8            42.1                  47.4
# 55   36.3        36.3            33.5                  39.2
# 56   47.1        47.1            44.0                  50.2
# 57   38.0        38.0            35.1                  41.0
# 58   22.9        22.9            20.3                  25.9
# 59   26.9        26.9            24.4                  29.5
# 60   48.0        48.0            41.3                  54.8
# 61   46.4        46.4            40.1                  52.9
# 62   40.8        40.8            34.5                  47.3
# 63   30.1        30.1            24.4                  36.5
# 64   25.9        25.9            20.4                  32.4
# 65   46.2        46.2            39.9                  52.5
# 66   30.7        30.7            25.1                  36.9
# 67   42.4        42.4            36.3                  48.7
# 68   33.0        33.0            27.7                  38.7
# 69   23.4        23.4            17.5                  30.5
# 70   28.5        28.5            23.7                  33.8
# 71   32.9        32.9            28.0                  38.3
# 72   46.4        46.4            40.7                  52.3
# 73   19.6        19.6            15.3                  24.7
# 74   49.1        49.1            43.2                  54.9
# 75   20.8        20.8            17.0                  25.2
# 76   30.9        30.9            26.2                  36.0
# 77   19.2        19.2            15.1                  24.1
# 78   42.8        42.8            37.6                  48.1
# 79   47.7        47.7            42.4                  53.1
# 80   49.7        49.7            43.6                  55.7
# 81   24.8        24.8            20.3                  29.9
# 82   35.5        35.5            30.0                  41.4
# 83   40.3        40.3            34.4                  46.5
# 84   13.9        13.9            9.9                   19.3
# 85   36.8        36.8            29.5                  44.8
# 86   40.8        40.8            33.7                  48.3
# 87   45.2        45.2            37.8                  52.8
# 88   47.2        47.2            39.3                  55.3
# 89   27.0        27.0            21.1                  33.8
# 90   18.4        18.4            16.0                  21.2
# 91   30.3        30.3            27.6                  33.1
# 92   43.3        43.3            40.1                  46.6
# 93   34.1        34.1            31.0                  37.4
# 94   34.2        34.2            31.1                  37.4
# 95   31.9        31.9            30.1                  33.8
# 96   20.6        20.6            18.9                  22.4
# 97   39.9        39.9            37.9                  41.8
# 98   45.9        45.9            43.9                  47.9
# 99   31.5        31.5            29.8                  33.3
# 100  45.6        45.6            31.9                  60.0
# 101  25.4        25.4            15.8                  38.2
# 102  16.6        16.6            8.0                   31.3
# 103  45.8        45.8            32.1                  60.3
# 104  35.3        35.3            22.4                  50.8
# 105 NaN         NaN             NaN                   NaN
# 106 NaN         NaN             NaN                   NaN
# 107 NaN         NaN             NaN                   NaN
# 108 NaN         NaN             NaN                   NaN
# 109 NaN         NaN             NaN                   NaN
# 110  26.5        26.5            23.3                  30.0
# 111  35.0        35.0            31.5                  38.7
# 112  49.7        49.7            45.7                  53.6
# 113  27.1        27.1            23.5                  30.9
# 114  37.5        37.5            33.6                  41.5
# 115  37.6        37.6            24.1                  53.3
# 116  36.6        36.6            23.1                  52.7
# 117  22.8        22.8            13.5                  35.9
# 118  38.8        38.8            25.4                  54.1
# 119  42.6        42.6            28.9                  57.5
# 120 NaN         NaN             NaN                   NaN
# 121 NaN         NaN             NaN                   NaN
# 122 NaN         NaN             NaN                   NaN
# 123 NaN         NaN             NaN                   NaN
# 124 NaN         NaN             NaN                   NaN
# 125 NaN         NaN             NaN                   NaN
# 126 NaN         NaN             NaN                   NaN
# 127 NaN         NaN             NaN                   NaN
# 128 NaN         NaN             NaN                   NaN
# 129 NaN         NaN             NaN                   NaN
# 130 NaN         NaN             NaN                   NaN
# 131 NaN         NaN             NaN                   NaN
# 132 NaN         NaN             NaN                   NaN
# 133 NaN         NaN             NaN                   NaN
# 134 NaN         NaN             NaN                   NaN
# 135  17.3        17.3            15.5                  19.3
# 136  33.3        33.3            31.1                  35.5
# 137  49.6        49.6            47.2                  52.0
# 138  36.8        36.8            34.5                  39.1
# 139  31.0        31.0            29.0                  33.1
#
#      sample_size    age_years
# 0    232.0        18 - 24
# 1    223.0        18 - 24
# 2    232.0        18 - 24
# 3    219.0        18 - 24
# 4    254.0        18 - 24
# 5    433.0        25 - 34
# 6    433.0        25 - 34
# 7    475.0        25 - 34
# 8    410.0        25 - 34
# 9    419.0        25 - 34
# 10   507.0        35 - 44
# 11   521.0        35 - 44
# 12   499.0        35 - 44
# 13   521.0        35 - 44
# 14   553.0        35 - 44
# 15   594.0        45 - 54
# 16   570.0        45 - 54
# 17   638.0        45 - 54
# 18   594.0        45 - 54
# 19   577.0        45 - 54
# 20   826.0        55 - 64
# 21   826.0        55 - 64
# 22   900.0        55 - 64
# 23   809.0        55 - 64
# 24   811.0        55 - 64
# 25   1641.0       65 or older
# 26   1641.0       65 or older
# 27   1642.0       65 or older
# 28   1607.0       65 or older
# 29   1758.0       65 or older
# 30   1671.0       NaN
# 31   1553.0       NaN
# 32   1566.0       NaN
# 33   1553.0       NaN
# 34   1555.0       NaN
# 35   1289.0       NaN
# 36   1194.0       NaN
# 37   1177.0       NaN
# 38   1194.0       NaN
# 39   1149.0       NaN
# 40   311.0        NaN
# 41   328.0        NaN
# 42   356.0        NaN
# 43   328.0        NaN
# 44   305.0        NaN
# 45   1245.0       NaN
# 46   1097.0       NaN
# 47   1113.0       NaN
# 48   1165.0       NaN
# 49   1165.0       NaN
# 50   2752.0       NaN
# 51   2477.0       NaN
# 52   2494.0       NaN
# 53   2494.0       NaN
# 54   2503.0       NaN
# 55   1753.0       NaN
# 56   1674.0       NaN
# 57   1753.0       NaN
# 58   1639.0       NaN
# 59   1826.0       NaN
# 60   393.0        NaN
# 61   430.0        NaN
# 62   409.0        NaN
# 63   409.0        NaN
# 64   387.0        NaN
# 65   475.0        NaN
# 66   475.0        NaN
# 67   457.0        NaN
# 68   495.0        NaN
# 69   453.0        NaN
# 70   504.0        NaN
# 71   522.0        NaN
# 72   504.0        NaN
# 73   474.0        NaN
# 74   486.0        NaN
# 75   589.0        NaN
# 76   569.0        NaN
# 77   551.0        NaN
# 78   569.0        NaN
# 79   559.0        NaN
# 80   440.0        NaN
# 81   455.0        NaN
# 82   441.0        NaN
# 83   441.0        NaN
# 84   434.0        NaN
# 85   246.0        NaN
# 86   273.0        NaN
# 87   279.0        NaN
# 88   252.0        NaN
# 89   273.0        NaN
# 90   1571.0       NaN
# 91   1808.0       NaN
# 92   1590.0       NaN
# 93   1576.0       NaN
# 94   1576.0       NaN
# 95   4247.0       NaN
# 96   4116.0       NaN
# 97   4247.0       NaN
# 98   4177.0       NaN
# 99   4578.0       NaN
# 100  80.0         NaN
# 101  88.0         NaN
# 102  76.0         NaN
# 103  81.0         NaN
# 104  81.0         NaN
# 105 NaN           NaN
# 106 NaN           NaN
# 107 NaN           NaN
# 108 NaN           NaN
# 109 NaN           NaN
# 110  1076.0       NaN
# 111  1172.0       NaN
# 112  1076.0       NaN
# 113  1031.0       NaN
# 114  1039.0       NaN
# 115  75.0         NaN
# 116  69.0         NaN
# 117  84.0         NaN
# 118  69.0         NaN
# 119  72.0         NaN
# 120 NaN           NaN
# 121 NaN           NaN
# 122 NaN           NaN
# 123 NaN           NaN
# 124 NaN           NaN
# 125 NaN           NaN
# 126 NaN           NaN
# 127 NaN           NaN
# 128 NaN           NaN
# 129 NaN           NaN
# 130 NaN           NaN
# 131 NaN           NaN
# 132 NaN           NaN
# 133 NaN           NaN
# 134 NaN           NaN
# 135  2805.0       NaN
# 136  2888.0       NaN
# 137  2854.0       NaN
# 138  2888.0       NaN
# 139  3080.0       NaN

# %%
#https://stackoverflow.com/questions/26246864/restoring-the-default-display-context-in-pandas
#reset default values
pd.reset_option('all')
