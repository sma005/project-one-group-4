# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import numpy as np
import requests
import time
import json
import string
from datetime import date 
from scipy.stats import linregress

#Notes: https://data.cdc.gov/Nutrition-Physical-Activity-and-Obesity/Nutrition-Physical-Activity-and-Obesity-Behavioral/hn4x-zwk7

# %%
#Import the API Key
#from api_key import api_key
#Don't need API Key

#import data
url = "https://data.cdc.gov/resource/hn4x-zwk7.json"

response = requests.get(url)
data = response.json()

data
# Out:
# [{'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '25.4',
#   'data_value_alt': '25.4',
#   'low_confidence_limit': '19.2',
#   'high_confidence_limit': '32.8',
#   'sample_size': '232.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '44.8',
#   'data_value_alt': '44.8',
#   'low_confidence_limit': '37.0',
#   'high_confidence_limit': '52.9',
#   'sample_size': '223.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '24.7',
#   'data_value_alt': '24.7',
#   'low_confidence_limit': '18.3',
#   'high_confidence_limit': '32.6',
#   'sample_size': '219.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '28.5',
#   'data_value_alt': '28.5',
#   'low_confidence_limit': '21.6',
#   'high_confidence_limit': '36.5',
#   'sample_size': '232.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '19.3',
#   'data_value_alt': '19.3',
#   'low_confidence_limit': '14.4',
#   'high_confidence_limit': '25.4',
#   'sample_size': '254.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '46.6',
#   'data_value_alt': '46.6',
#   'low_confidence_limit': '41.0',
#   'high_confidence_limit': '52.2',
#   'sample_size': '433.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '19.3',
#   'data_value_alt': '19.3',
#   'low_confidence_limit': '14.4',
#   'high_confidence_limit': '25.4',
#   'sample_size': '254.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '24.7',
#   'data_value_alt': '24.7',
#   'low_confidence_limit': '18.3',
#   'high_confidence_limit': '32.6',
#   'sample_size': '219.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '28.5',
#   'data_value_alt': '28.5',
#   'low_confidence_limit': '21.6',
#   'high_confidence_limit': '36.5',
#   'sample_size': '232.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '46.6',
#   'data_value_alt': '46.6',
#   'low_confidence_limit': '41.0',
#   'high_confidence_limit': '52.2',
#   'sample_size': '433.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '21.1',
#   'data_value_alt': '21.1',
#   'low_confidence_limit': '17.1',
#   'high_confidence_limit': '25.8',
#   'sample_size': '433.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '20.3',
#   'data_value_alt': '20.3',
#   'low_confidence_limit': '15.8',
#   'high_confidence_limit': '25.7',
#   'sample_size': '410.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '23.3',
#   'data_value_alt': '23.3',
#   'low_confidence_limit': '19.2',
#   'high_confidence_limit': '28.0',
#   'sample_size': '475.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '49.4',
#   'data_value_alt': '49.4',
#   'low_confidence_limit': '43.7',
#   'high_confidence_limit': '55.1',
#   'sample_size': '419.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '45.8',
#   'data_value_alt': '45.8',
#   'low_confidence_limit': '40.6',
#   'high_confidence_limit': '51.1',
#   'sample_size': '521.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '49.4',
#   'data_value_alt': '49.4',
#   'low_confidence_limit': '43.7',
#   'high_confidence_limit': '55.1',
#   'sample_size': '419.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '23.3',
#   'data_value_alt': '23.3',
#   'low_confidence_limit': '19.2',
#   'high_confidence_limit': '28.0',
#   'sample_size': '475.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '44.5',
#   'data_value_alt': '44.5',
#   'low_confidence_limit': '39.2',
#   'high_confidence_limit': '49.8',
#   'sample_size': '507.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '31.8',
#   'data_value_alt': '31.8',
#   'low_confidence_limit': '27.2',
#   'high_confidence_limit': '36.8',
#   'sample_size': '521.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '49.2',
#   'data_value_alt': '49.2',
#   'low_confidence_limit': '44.3',
#   'high_confidence_limit': '54.0',
#   'sample_size': '577.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '19.5',
#   'data_value_alt': '19.5',
#   'low_confidence_limit': '15.7',
#   'high_confidence_limit': '23.9',
#   'sample_size': '570.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '46.4',
#   'data_value_alt': '46.4',
#   'low_confidence_limit': '41.6',
#   'high_confidence_limit': '51.2',
#   'sample_size': '594.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '19.5',
#   'data_value_alt': '19.5',
#   'low_confidence_limit': '15.7',
#   'high_confidence_limit': '23.9',
#   'sample_size': '570.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '35.6',
#   'data_value_alt': '35.6',
#   'low_confidence_limit': '31.1',
#   'high_confidence_limit': '40.3',
#   'sample_size': '638.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '33.8',
#   'data_value_alt': '33.8',
#   'low_confidence_limit': '29.4',
#   'high_confidence_limit': '38.6',
#   'sample_size': '594.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '21.2',
#   'data_value_alt': '21.2',
#   'low_confidence_limit': '17.8',
#   'high_confidence_limit': '25.0',
#   'sample_size': '811.0',
#   'age_years': '55 - 64',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '55 - 64',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR5564'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '48.4',
#   'data_value_alt': '48.4',
#   'low_confidence_limit': '44.1',
#   'high_confidence_limit': '52.8',
#   'sample_size': '809.0',
#   'age_years': '55 - 64',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '55 - 64',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR5564'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '32.7',
#   'data_value_alt': '32.7',
#   'low_confidence_limit': '28.9',
#   'high_confidence_limit': '36.7',
#   'sample_size': '826.0',
#   'age_years': '55 - 64',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '55 - 64',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR5564'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '39.1',
#   'data_value_alt': '39.1',
#   'low_confidence_limit': '35.2',
#   'high_confidence_limit': '43.2',
#   'sample_size': '900.0',
#   'age_years': '55 - 64',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '55 - 64',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR5564'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '44.4',
#   'data_value_alt': '44.4',
#   'low_confidence_limit': '40.2',
#   'high_confidence_limit': '48.7',
#   'sample_size': '826.0',
#   'age_years': '55 - 64',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '55 - 64',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR5564'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '30.9',
#   'data_value_alt': '30.9',
#   'low_confidence_limit': '28.1',
#   'high_confidence_limit': '33.8',
#   'sample_size': '1641.0',
#   'age_years': '65 or older',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '65 or older',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR65PLUS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '41.3',
#   'data_value_alt': '41.3',
#   'low_confidence_limit': '38.3',
#   'high_confidence_limit': '44.4',
#   'sample_size': '1758.0',
#   'age_years': '65 or older',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '65 or older',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR65PLUS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '21.7',
#   'data_value_alt': '21.7',
#   'low_confidence_limit': '19.1',
#   'high_confidence_limit': '24.5',
#   'sample_size': '1607.0',
#   'age_years': '65 or older',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '65 or older',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR65PLUS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '39.4',
#   'data_value_alt': '39.4',
#   'low_confidence_limit': '36.3',
#   'high_confidence_limit': '42.6',
#   'sample_size': '1641.0',
#   'age_years': '65 or older',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '65 or older',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR65PLUS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '41.1',
#   'data_value_alt': '41.1',
#   'low_confidence_limit': '38.0',
#   'high_confidence_limit': '44.3',
#   'sample_size': '1642.0',
#   'age_years': '65 or older',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '65 or older',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR65PLUS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '19.8',
#   'data_value_alt': '19.8',
#   'low_confidence_limit': '17.7',
#   'high_confidence_limit': '22.0',
#   'sample_size': '1671.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '34.2',
#   'data_value_alt': '34.2',
#   'low_confidence_limit': '31.4',
#   'high_confidence_limit': '37.2',
#   'sample_size': '1553.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '40.5',
#   'data_value_alt': '40.5',
#   'low_confidence_limit': '37.5',
#   'high_confidence_limit': '43.5',
#   'sample_size': '1566.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '15.5',
#   'data_value_alt': '15.5',
#   'low_confidence_limit': '13.3',
#   'high_confidence_limit': '17.9',
#   'sample_size': '1555.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '34.3',
#   'data_value_alt': '34.3',
#   'low_confidence_limit': '31.5',
#   'high_confidence_limit': '37.3',
#   'sample_size': '1553.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '34.2',
#   'data_value_alt': '34.2',
#   'low_confidence_limit': '31.4',
#   'high_confidence_limit': '37.2',
#   'sample_size': '1553.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '40.5',
#   'data_value_alt': '40.5',
#   'low_confidence_limit': '37.5',
#   'high_confidence_limit': '43.5',
#   'sample_size': '1566.0',
#   'education': 'College graduate',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'College graduate',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOGRAD'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '42.6',
#   'data_value_alt': '42.6',
#   'low_confidence_limit': '39.1',
#   'high_confidence_limit': '46.1',
#   'sample_size': '1194.0',
#   'education': 'Some college or technical school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Some college or technical school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOTEC'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '15.0',
#   'data_value_alt': '15.0',
#   'low_confidence_limit': '12.6',
#   'high_confidence_limit': '17.8',
#   'sample_size': '1149.0',
#   'education': 'Some college or technical school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Some college or technical school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOTEC'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '47.6',
#   'data_value_alt': '47.6',
#   'low_confidence_limit': '44.0',
#   'high_confidence_limit': '51.2',
#   'sample_size': '1177.0',
#   'education': 'Some college or technical school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Some college or technical school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOTEC'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '31.6',
#   'data_value_alt': '31.6',
#   'low_confidence_limit': '28.4',
#   'high_confidence_limit': '35.0',
#   'sample_size': '1194.0',
#   'education': 'Some college or technical school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Some college or technical school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUCOTEC'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '44.4',
#   'data_value_alt': '44.4',
#   'low_confidence_limit': '37.5',
#   'high_confidence_limit': '51.7',
#   'sample_size': '311.0',
#   'education': 'Less than high school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Less than high school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '33.1',
#   'data_value_alt': '33.1',
#   'low_confidence_limit': '27.1',
#   'high_confidence_limit': '39.7',
#   'sample_size': '328.0',
#   'education': 'Less than high school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Less than high school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '46.9',
#   'data_value_alt': '46.9',
#   'low_confidence_limit': '40.4',
#   'high_confidence_limit': '53.5',
#   'sample_size': '356.0',
#   'education': 'Less than high school',
#   'geolocation': {'latitude': '32.84057112200048',
#    'longitude': '-86.63186076199969',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '01',
#   'stratificationcategory1': 'Education',
#   'stratification1': 'Less than high school',
#   'stratificationcategoryid1': 'EDU',
#   'stratificationid1': 'EDUHS'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '27.8',
#   'data_value_alt': '27.8',
#   'low_confidence_limit': '22.0',
# ...
#   'data_value_alt': '22.5',
#   'low_confidence_limit': '16.1',
#   'high_confidence_limit': '30.6',
#   'sample_size': '180.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '35.9',
#   'data_value_alt': '35.9',
#   'low_confidence_limit': '27.3',
#   'high_confidence_limit': '45.5',
#   'sample_size': '167.0',
#   'age_years': '18 - 24',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '18 - 24',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR1824'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '24.7',
#   'data_value_alt': '24.7',
#   'low_confidence_limit': '19.4',
#   'high_confidence_limit': '30.8',
#   'sample_size': '372.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '24.1',
#   'data_value_alt': '24.1',
#   'low_confidence_limit': '19.1',
#   'high_confidence_limit': '30.1',
#   'sample_size': '322.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '31.2',
#   'data_value_alt': '31.2',
#   'low_confidence_limit': '25.3',
#   'high_confidence_limit': '37.7',
#   'sample_size': '329.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '31.4',
#   'data_value_alt': '31.4',
#   'low_confidence_limit': '25.5',
#   'high_confidence_limit': '37.9',
#   'sample_size': '329.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '39.5',
#   'data_value_alt': '39.5',
#   'low_confidence_limit': '33.0',
#   'high_confidence_limit': '46.3',
#   'sample_size': '330.0',
#   'age_years': '25 - 34',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '25 - 34',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR2534'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '39.8',
#   'data_value_alt': '39.8',
#   'low_confidence_limit': '33.8',
#   'high_confidence_limit': '46.2',
#   'sample_size': '412.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '38.3',
#   'data_value_alt': '38.3',
#   'low_confidence_limit': '32.4',
#   'high_confidence_limit': '44.6',
#   'sample_size': '419.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '20.4',
#   'data_value_alt': '20.4',
#   'low_confidence_limit': '15.6',
#   'high_confidence_limit': '26.1',
#   'sample_size': '397.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '22.3',
#   'data_value_alt': '22.3',
#   'low_confidence_limit': '17.9',
#   'high_confidence_limit': '27.4',
#   'sample_size': '487.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '38.3',
#   'data_value_alt': '38.3',
#   'low_confidence_limit': '32.4',
#   'high_confidence_limit': '44.6',
#   'sample_size': '419.0',
#   'age_years': '35 - 44',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '35 - 44',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR3544'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming fruit less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '45.5',
#   'data_value_alt': '45.5',
#   'low_confidence_limit': '39.8',
#   'high_confidence_limit': '51.4',
#   'sample_size': '479.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q018',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have an overweight classification',
#   'data_value_type': 'Value',
#   'data_value': '33.9',
#   'data_value_alt': '33.9',
#   'low_confidence_limit': '28.8',
#   'high_confidence_limit': '39.3',
#   'sample_size': '489.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q037',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Fruits and Vegetables',
#   'topic': 'Fruits and Vegetables - Behavior',
#   'question': 'Percent of adults who report consuming vegetables less than one time daily',
#   'data_value_type': 'Value',
#   'data_value': '15.2',
#   'data_value_alt': '15.2',
#   'low_confidence_limit': '11.4',
#   'high_confidence_limit': '20.0',
#   'sample_size': '465.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'FV',
#   'topicid': 'FV1',
#   'questionid': 'Q019',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Obesity / Weight Status',
#   'topic': 'Obesity / Weight Status',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'data_value_type': 'Value',
#   'data_value': '39.6',
#   'data_value_alt': '39.6',
#   'low_confidence_limit': '34.2',
#   'high_confidence_limit': '45.2',
#   'sample_size': '489.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'OWS',
#   'topicid': 'OWS1',
#   'questionid': 'Q036',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'},
#  {'yearstart': '2021',
#   'yearend': '2021',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'class': 'Physical Activity',
#   'topic': 'Physical Activity - Behavior',
#   'question': 'Percent of adults who engage in no leisure-time physical activity',
#   'data_value_type': 'Value',
#   'data_value': '25.6',
#   'data_value_alt': '25.6',
#   'low_confidence_limit': '21.1',
#   'high_confidence_limit': '30.6',
#   'sample_size': '562.0',
#   'age_years': '45 - 54',
#   'geolocation': {'latitude': '39.008830667000495',
#    'longitude': '-75.57774116799965',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'classid': 'PA',
#   'topicid': 'PA1',
#   'questionid': 'Q047',
#   'datavaluetypeid': 'VALUE',
#   'locationid': '10',
#   'stratificationcategory1': 'Age (years)',
#   'stratification1': '45 - 54',
#   'stratificationcategoryid1': 'AGEYR',
#   'stratificationid1': 'AGEYR4554'}]

# %%
# Convert the cities weather data into a Pandas DataFrame
data_df = pd.DataFrame(data)

data_df = data_df[['yearend','locationabbr','question','data_value','sample_size','age_years']]

data_df['data_value'] = data_df.data_value.astype(float)
data_df['sample_size'] = data_df.sample_size.astype(float)

data_df.info()
# Show Record Count
data_df
#data_df.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yearend       1000 non-null   object
#  1   locationabbr  1000 non-null   object
#  2   question      1000 non-null   object
#  3   data_value    930 non-null    float64
#  4   sample_size   930 non-null    float64
#  5   age_years     230 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 47.0+ KB
#     yearend locationabbr                                           question  \
# 0      2021           AL  Percent of adults who report consuming fruit l...
# 1      2021           AL  Percent of adults aged 18 years and older who ...
# 2      2021           AL  Percent of adults who engage in no leisure-tim...
# 3      2021           AL  Percent of adults who report consuming vegetab...
# 4      2021           AL  Percent of adults aged 18 years and older who ...
# ..      ...          ...                                                ...
# 995    2021           DE  Percent of adults who report consuming fruit l...
# 996    2021           DE  Percent of adults aged 18 years and older who ...
# 997    2021           DE  Percent of adults who report consuming vegetab...
# 998    2021           DE  Percent of adults aged 18 years and older who ...
# 999    2021           DE  Percent of adults who engage in no leisure-tim...
#
#      data_value  sample_size age_years
# 0          44.8        223.0   18 - 24
# 1          25.4        232.0   18 - 24
# 2          19.3        254.0   18 - 24
# 3          24.7        219.0   18 - 24
# 4          28.5        232.0   18 - 24
# ..          ...          ...       ...
# 995        45.5        479.0   45 - 54
# 996        33.9        489.0   45 - 54
# 997        15.2        465.0   45 - 54
# 998        39.6        489.0   45 - 54
# 999        25.6        562.0   45 - 54
#
# [1000 rows x 6 columns]

# %%
#df2['age_bmi'] = df['age'] *df['bmi']
data_df['calculated_num_obese'] = round(data_df['sample_size'] * data_df['data_value'] * .01)
data_df
# Out:
#     yearend locationabbr                                           question  \
# 0      2021           AL  Percent of adults who report consuming fruit l...
# 1      2021           AL  Percent of adults aged 18 years and older who ...
# 2      2021           AL  Percent of adults who engage in no leisure-tim...
# 3      2021           AL  Percent of adults who report consuming vegetab...
# 4      2021           AL  Percent of adults aged 18 years and older who ...
# ..      ...          ...                                                ...
# 995    2021           DE  Percent of adults who report consuming fruit l...
# 996    2021           DE  Percent of adults aged 18 years and older who ...
# 997    2021           DE  Percent of adults who report consuming vegetab...
# 998    2021           DE  Percent of adults aged 18 years and older who ...
# 999    2021           DE  Percent of adults who engage in no leisure-tim...
#
#      data_value  sample_size age_years  calculated_num_obese
# 0          44.8        223.0   18 - 24                 100.0
# 1          25.4        232.0   18 - 24                  59.0
# 2          19.3        254.0   18 - 24                  49.0
# 3          24.7        219.0   18 - 24                  54.0
# 4          28.5        232.0   18 - 24                  66.0
# ..          ...          ...       ...                   ...
# 995        45.5        479.0   45 - 54                 218.0
# 996        33.9        489.0   45 - 54                 166.0
# 997        15.2        465.0   45 - 54                  71.0
# 998        39.6        489.0   45 - 54                 194.0
# 999        25.6        562.0   45 - 54                 144.0
#
# [1000 rows x 7 columns]

# %%
num_of_participants = data_df['sample_size'].sum()
num_of_participants
# Out:
# 1400392.0

# %%
#These are the questions this dataset answers
list_of_questions = data_df['question'].unique()
print(sorted(list_of_questions))
# Out:
# ['Percent of adults aged 18 years and older who have an overweight classification', 'Percent of adults aged 18 years and older who have obesity', 'Percent of adults who engage in no leisure-time physical activity', 'Percent of adults who report consuming fruit less than one time daily', 'Percent of adults who report consuming vegetables less than one time daily']

# %%
#These are the age groups
age_groups = data_df['age_years'].unique()
print(age_groups)
# Out:
# ['18 - 24' '25 - 34' '35 - 44' '45 - 54' '55 - 64' '65 or older' nan]

# %%
overweight_df = data_df[data_df['question'] == 'Percent of adults aged 18 years and older who have an overweight classification']
overweight_df
# Out:
#     yearend locationabbr                                           question  \
# 1      2021           AL  Percent of adults aged 18 years and older who ...
# 9      2021           AL  Percent of adults aged 18 years and older who ...
# 12     2021           AL  Percent of adults aged 18 years and older who ...
# 19     2021           AL  Percent of adults aged 18 years and older who ...
# 20     2021           AL  Percent of adults aged 18 years and older who ...
# ..      ...          ...                                                ...
# 978    2021           CT  Percent of adults aged 18 years and older who ...
# 980    2021           DE  Percent of adults aged 18 years and older who ...
# 989    2021           DE  Percent of adults aged 18 years and older who ...
# 990    2021           DE  Percent of adults aged 18 years and older who ...
# 999    2021           DE  Percent of adults aged 18 years and older who ...
#
#      data_value  sample_size age_years
# 1          28.5        232.0   18 - 24
# 9          21.1        433.0   25 - 34
# 12         31.8        521.0   35 - 44
# 19         33.8        594.0   45 - 54
# 20         32.7        826.0   55 - 64
# ..          ...          ...       ...
# 978        35.6       5161.0       NaN
# 980        22.5        180.0   18 - 24
# 989        31.2        329.0   25 - 34
# 990        35.5        419.0   35 - 44
# 999        33.9        489.0   45 - 54
#
# [200 rows x 6 columns]

# %%
obese_df = data_df[data_df['question'] == 'Percent of adults aged 18 years and older who have obesity']
obese_df
# Out:
#     yearend locationabbr                                           question  \
# 3      2021           AL  Percent of adults aged 18 years and older who ...
# 6      2021           AL  Percent of adults aged 18 years and older who ...
# 14     2021           AL  Percent of adults aged 18 years and older who ...
# 16     2021           AL  Percent of adults aged 18 years and older who ...
# 23     2021           AL  Percent of adults aged 18 years and older who ...
# ..      ...          ...                                                ...
# 975    2021           CT  Percent of adults aged 18 years and older who ...
# 984    2021           DE  Percent of adults aged 18 years and older who ...
# 988    2021           DE  Percent of adults aged 18 years and older who ...
# 991    2021           DE  Percent of adults aged 18 years and older who ...
# 996    2021           DE  Percent of adults aged 18 years and older who ...
#
#      data_value  sample_size age_years
# 3          25.4        232.0   18 - 24
# 6          46.6        433.0   25 - 34
# 14         45.8        521.0   35 - 44
# 16         46.4        594.0   45 - 54
# 23         44.4        826.0   55 - 64
# ..          ...          ...       ...
# 975        28.8       5161.0       NaN
# 984        17.5        180.0   18 - 24
# 988        31.4        329.0   25 - 34
# 991        38.3        419.0   35 - 44
# 996        39.6        489.0   45 - 54
#
# [200 rows x 6 columns]

# %%
no_leisure_df = data_df[data_df['question'] == 'Percent of adults who engage in no leisure-time physical activity']
no_leisure_df
# Out:
#     yearend locationabbr                                           question  \
# 0      2021           AL  Percent of adults who engage in no leisure-tim...
# 7      2021           AL  Percent of adults who engage in no leisure-tim...
# 11     2021           AL  Percent of adults who engage in no leisure-tim...
# 15     2021           AL  Percent of adults who engage in no leisure-tim...
# 21     2021           AL  Percent of adults who engage in no leisure-tim...
# ..      ...          ...                                                ...
# 977    2021           CT  Percent of adults who engage in no leisure-tim...
# 981    2021           DE  Percent of adults who engage in no leisure-tim...
# 987    2021           DE  Percent of adults who engage in no leisure-tim...
# 992    2021           DE  Percent of adults who engage in no leisure-tim...
# 995    2021           DE  Percent of adults who engage in no leisure-tim...
#
#      data_value  sample_size age_years
# 0          19.3        254.0   18 - 24
# 7          23.3        475.0   25 - 34
# 11         22.4        553.0   35 - 44
# 15         35.6        638.0   45 - 54
# 21         39.1        900.0   55 - 64
# ..          ...          ...       ...
# 977        18.4       5949.0       NaN
# 981        21.3        210.0   18 - 24
# 987        24.7        372.0   25 - 34
# 992        22.3        487.0   35 - 44
# 995        25.6        562.0   45 - 54
#
# [200 rows x 6 columns]

# %%
no_fruit_df = data_df[data_df['question'] == 'Percent of adults who report consuming fruit less than one time daily']
no_fruit_df
# Out:
#     yearend locationabbr                                           question  \
# 4      2021           AL  Percent of adults who report consuming fruit l...
# 8      2021           AL  Percent of adults who report consuming fruit l...
# 10     2021           AL  Percent of adults who report consuming fruit l...
# 17     2021           AL  Percent of adults who report consuming fruit l...
# 22     2021           AL  Percent of adults who report consuming fruit l...
# ..      ...          ...                                                ...
# 976    2021           CT  Percent of adults who report consuming fruit l...
# 983    2021           DE  Percent of adults who report consuming fruit l...
# 985    2021           DE  Percent of adults who report consuming fruit l...
# 993    2021           DE  Percent of adults who report consuming fruit l...
# 997    2021           DE  Percent of adults who report consuming fruit l...
#
#      data_value  sample_size age_years
# 4          44.8        223.0   18 - 24
# 8          49.4        419.0   25 - 34
# 10         44.5        507.0   35 - 44
# 17         49.2        577.0   45 - 54
# 22         48.4        809.0   55 - 64
# ..          ...          ...       ...
# 976        35.7       5113.0       NaN
# 983        44.2        175.0   18 - 24
# 985        39.5        330.0   25 - 34
# 993        39.8        412.0   35 - 44
# 997        45.5        479.0   45 - 54
#
# [200 rows x 6 columns]

# %%
no_vegetables_df = data_df[data_df['question'] == 'Percent of adults who report consuming vegetables less than one time daily']
no_vegetables_df
# Out:
#     yearend locationabbr                                           question  \
# 2      2021           AL  Percent of adults who report consuming vegetab...
# 5      2021           AL  Percent of adults who report consuming vegetab...
# 13     2021           AL  Percent of adults who report consuming vegetab...
# 18     2021           AL  Percent of adults who report consuming vegetab...
# 24     2021           AL  Percent of adults who report consuming vegetab...
# ..      ...          ...                                                ...
# 979    2021           CT  Percent of adults who report consuming vegetab...
# 982    2021           DE  Percent of adults who report consuming vegetab...
# 986    2021           DE  Percent of adults who report consuming vegetab...
# 994    2021           DE  Percent of adults who report consuming vegetab...
# 998    2021           DE  Percent of adults who report consuming vegetab...
#
#      data_value  sample_size age_years
# 2          24.7        219.0   18 - 24
# 5          20.3        410.0   25 - 34
# 13         16.7        499.0   35 - 44
# 18         19.5        570.0   45 - 54
# 24         21.2        811.0   55 - 64
# ..          ...          ...       ...
# 979        16.2       4932.0       NaN
# 982        35.9        167.0   18 - 24
# 986        24.1        322.0   25 - 34
# 994        20.4        397.0   35 - 44
# 998        15.2        465.0   45 - 54
#
# [200 rows x 6 columns]

# %%
alabama_df = data_df[data_df['locationabbr'] == 'AL']
alabama_df
# Out:
#     yearend locationabbr                                           question  \
# 0      2021           AL  Percent of adults who engage in no leisure-tim...
# 1      2021           AL  Percent of adults aged 18 years and older who ...
# 2      2021           AL  Percent of adults who report consuming vegetab...
# 3      2021           AL  Percent of adults aged 18 years and older who ...
# 4      2021           AL  Percent of adults who report consuming fruit l...
# ..      ...          ...                                                ...
# 135    2021           AL  Percent of adults who engage in no leisure-tim...
# 136    2021           AL  Percent of adults aged 18 years and older who ...
# 137    2021           AL  Percent of adults aged 18 years and older who ...
# 138    2021           AL  Percent of adults who report consuming fruit l...
# 139    2021           AL  Percent of adults who report consuming vegetab...
#
#      data_value  sample_size age_years
# 0          19.3        254.0   18 - 24
# 1          28.5        232.0   18 - 24
# 2          24.7        219.0   18 - 24
# 3          25.4        232.0   18 - 24
# 4          44.8        223.0   18 - 24
# ..          ...          ...       ...
# 135        31.0       3080.0       NaN
# 136        33.3       2888.0       NaN
# 137        36.8       2888.0       NaN
# 138        49.6       2854.0       NaN
# 139        17.3       2805.0       NaN
#
# [140 rows x 6 columns]

# %%
#https://www.geeksforgeeks.org/how-to-print-an-entire-pandas-dataframe-in-python/

# Permanently changes the pandas settings
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 0)

alabama_df
# Out:
#     yearend locationabbr  \
# 0    2021    AL
# 1    2021    AL
# 2    2021    AL
# 3    2021    AL
# 4    2021    AL
# 5    2021    AL
# 6    2021    AL
# 7    2021    AL
# 8    2021    AL
# 9    2021    AL
# 10   2021    AL
# 11   2021    AL
# 12   2021    AL
# 13   2021    AL
# 14   2021    AL
# 15   2021    AL
# 16   2021    AL
# 17   2021    AL
# 18   2021    AL
# 19   2021    AL
# 20   2021    AL
# 21   2021    AL
# 22   2021    AL
# 23   2021    AL
# 24   2021    AL
# 25   2021    AL
# 26   2021    AL
# 27   2021    AL
# 28   2021    AL
# 29   2021    AL
# 30   2021    AL
# 31   2021    AL
# 32   2021    AL
# 33   2021    AL
# 34   2021    AL
# 35   2021    AL
# 36   2021    AL
# 37   2021    AL
# 38   2021    AL
# 39   2021    AL
# 40   2021    AL
# 41   2021    AL
# 42   2021    AL
# 43   2021    AL
# 44   2021    AL
# 45   2021    AL
# 46   2021    AL
# 47   2021    AL
# 48   2021    AL
# 49   2021    AL
# 50   2021    AL
# 51   2021    AL
# 52   2021    AL
# 53   2021    AL
# 54   2021    AL
# 55   2021    AL
# 56   2021    AL
# 57   2021    AL
# 58   2021    AL
# 59   2021    AL
# 60   2021    AL
# 61   2021    AL
# 62   2021    AL
# 63   2021    AL
# 64   2021    AL
# 65   2021    AL
# 66   2021    AL
# 67   2021    AL
# 68   2021    AL
# 69   2021    AL
# 70   2021    AL
# 71   2021    AL
# 72   2021    AL
# 73   2021    AL
# 74   2021    AL
# 75   2021    AL
# 76   2021    AL
# 77   2021    AL
# 78   2021    AL
# 79   2021    AL
# 80   2021    AL
# 81   2021    AL
# 82   2021    AL
# 83   2021    AL
# 84   2021    AL
# 85   2021    AL
# 86   2021    AL
# 87   2021    AL
# 88   2021    AL
# 89   2021    AL
# 90   2021    AL
# 91   2021    AL
# 92   2021    AL
# 93   2021    AL
# 94   2021    AL
# 95   2021    AL
# 96   2021    AL
# 97   2021    AL
# 98   2021    AL
# 99   2021    AL
# 100  2021    AL
# 101  2021    AL
# 102  2021    AL
# 103  2021    AL
# 104  2021    AL
# 105  2021    AL
# 106  2021    AL
# 107  2021    AL
# 108  2021    AL
# 109  2021    AL
# 110  2021    AL
# 111  2021    AL
# 112  2021    AL
# 113  2021    AL
# 114  2021    AL
# 115  2021    AL
# 116  2021    AL
# 117  2021    AL
# 118  2021    AL
# 119  2021    AL
# 120  2021    AL
# 121  2021    AL
# 122  2021    AL
# 123  2021    AL
# 124  2021    AL
# 125  2021    AL
# 126  2021    AL
# 127  2021    AL
# 128  2021    AL
# 129  2021    AL
# 130  2021    AL
# 131  2021    AL
# 132  2021    AL
# 133  2021    AL
# 134  2021    AL
# 135  2021    AL
# 136  2021    AL
# 137  2021    AL
# 138  2021    AL
# 139  2021    AL
#
#                                                                             question  \
# 0    Percent of adults who engage in no leisure-time physical activity
# 1    Percent of adults aged 18 years and older who have an overweight classification
# 2    Percent of adults who report consuming vegetables less than one time daily
# 3    Percent of adults aged 18 years and older who have obesity
# 4    Percent of adults who report consuming fruit less than one time daily
# 5    Percent of adults who report consuming vegetables less than one time daily
# 6    Percent of adults aged 18 years and older who have obesity
# 7    Percent of adults who engage in no leisure-time physical activity
# 8    Percent of adults who report consuming fruit less than one time daily
# 9    Percent of adults aged 18 years and older who have an overweight classification
# 10   Percent of adults who report consuming fruit less than one time daily
# 11   Percent of adults who engage in no leisure-time physical activity
# 12   Percent of adults aged 18 years and older who have an overweight classification
# 13   Percent of adults who report consuming vegetables less than one time daily
# 14   Percent of adults aged 18 years and older who have obesity
# 15   Percent of adults who engage in no leisure-time physical activity
# 16   Percent of adults aged 18 years and older who have obesity
# 17   Percent of adults who report consuming fruit less than one time daily
# 18   Percent of adults who report consuming vegetables less than one time daily
# 19   Percent of adults aged 18 years and older who have an overweight classification
# 20   Percent of adults aged 18 years and older who have an overweight classification
# 21   Percent of adults who engage in no leisure-time physical activity
# 22   Percent of adults who report consuming fruit less than one time daily
# 23   Percent of adults aged 18 years and older who have obesity
# 24   Percent of adults who report consuming vegetables less than one time daily
# 25   Percent of adults who report consuming fruit less than one time daily
# 26   Percent of adults aged 18 years and older who have obesity
# 27   Percent of adults who engage in no leisure-time physical activity
# 28   Percent of adults who report consuming vegetables less than one time daily
# 29   Percent of adults aged 18 years and older who have an overweight classification
# 30   Percent of adults who engage in no leisure-time physical activity
# 31   Percent of adults aged 18 years and older who have obesity
# 32   Percent of adults who report consuming vegetables less than one time daily
# 33   Percent of adults who report consuming fruit less than one time daily
# 34   Percent of adults aged 18 years and older who have an overweight classification
# 35   Percent of adults who engage in no leisure-time physical activity
# 36   Percent of adults who report consuming fruit less than one time daily
# 37   Percent of adults aged 18 years and older who have an overweight classification
# 38   Percent of adults who report consuming vegetables less than one time daily
# 39   Percent of adults aged 18 years and older who have obesity
# 40   Percent of adults who engage in no leisure-time physical activity
# 41   Percent of adults who report consuming fruit less than one time daily
# 42   Percent of adults aged 18 years and older who have an overweight classification
# 43   Percent of adults aged 18 years and older who have obesity
# 44   Percent of adults who report consuming vegetables less than one time daily
# 45   Percent of adults aged 18 years and older who have an overweight classification
# 46   Percent of adults aged 18 years and older who have obesity
# 47   Percent of adults who report consuming fruit less than one time daily
# 48   Percent of adults who report consuming vegetables less than one time daily
# 49   Percent of adults who engage in no leisure-time physical activity
# 50   Percent of adults who report consuming vegetables less than one time daily
# 51   Percent of adults who report consuming fruit less than one time daily
# 52   Percent of adults aged 18 years and older who have obesity
# 53   Percent of adults aged 18 years and older who have an overweight classification
# 54   Percent of adults who engage in no leisure-time physical activity
# 55   Percent of adults aged 18 years and older who have obesity
# 56   Percent of adults who report consuming fruit less than one time daily
# 57   Percent of adults aged 18 years and older who have an overweight classification
# 58   Percent of adults who engage in no leisure-time physical activity
# 59   Percent of adults who report consuming vegetables less than one time daily
# 60   Percent of adults aged 18 years and older who have an overweight classification
# 61   Percent of adults who report consuming vegetables less than one time daily
# 62   Percent of adults who report consuming fruit less than one time daily
# 63   Percent of adults who engage in no leisure-time physical activity
# 64   Percent of adults aged 18 years and older who have obesity
# 65   Percent of adults who engage in no leisure-time physical activity
# 66   Percent of adults aged 18 years and older who have an overweight classification
# 67   Percent of adults who report consuming vegetables less than one time daily
# 68   Percent of adults aged 18 years and older who have obesity
# 69   Percent of adults who report consuming fruit less than one time daily
# 70   Percent of adults who report consuming vegetables less than one time daily
# 71   Percent of adults aged 18 years and older who have obesity
# 72   Percent of adults aged 18 years and older who have an overweight classification
# 73   Percent of adults who report consuming fruit less than one time daily
# 74   Percent of adults who engage in no leisure-time physical activity
# 75   Percent of adults who engage in no leisure-time physical activity
# 76   Percent of adults who report consuming fruit less than one time daily
# 77   Percent of adults who report consuming vegetables less than one time daily
# 78   Percent of adults aged 18 years and older who have an overweight classification
# 79   Percent of adults aged 18 years and older who have obesity
# 80   Percent of adults who engage in no leisure-time physical activity
# 81   Percent of adults who report consuming fruit less than one time daily
# 82   Percent of adults aged 18 years and older who have an overweight classification
# 83   Percent of adults who report consuming vegetables less than one time daily
# 84   Percent of adults aged 18 years and older who have obesity
# 85   Percent of adults who report consuming fruit less than one time daily
# 86   Percent of adults aged 18 years and older who have an overweight classification
# 87   Percent of adults who report consuming vegetables less than one time daily
# 88   Percent of adults aged 18 years and older who have obesity
# 89   Percent of adults who engage in no leisure-time physical activity
# 90   Percent of adults who engage in no leisure-time physical activity
# 91   Percent of adults aged 18 years and older who have obesity
# 92   Percent of adults who report consuming fruit less than one time daily
# 93   Percent of adults who report consuming vegetables less than one time daily
# 94   Percent of adults aged 18 years and older who have an overweight classification
# 95   Percent of adults aged 18 years and older who have an overweight classification
# 96   Percent of adults who engage in no leisure-time physical activity
# 97   Percent of adults who report consuming fruit less than one time daily
# 98   Percent of adults aged 18 years and older who have obesity
# 99   Percent of adults who report consuming vegetables less than one time daily
# 100  Percent of adults aged 18 years and older who have an overweight classification
# 101  Percent of adults aged 18 years and older who have obesity
# 102  Percent of adults who report consuming vegetables less than one time daily
# 103  Percent of adults who engage in no leisure-time physical activity
# 104  Percent of adults who report consuming fruit less than one time daily
# 105  Percent of adults who engage in no leisure-time physical activity
# 106  Percent of adults who report consuming fruit less than one time daily
# 107  Percent of adults aged 18 years and older who have an overweight classification
# 108  Percent of adults who report consuming vegetables less than one time daily
# 109  Percent of adults aged 18 years and older who have obesity
# 110  Percent of adults who engage in no leisure-time physical activity
# 111  Percent of adults aged 18 years and older who have an overweight classification
# 112  Percent of adults who report consuming vegetables less than one time daily
# 113  Percent of adults who report consuming fruit less than one time daily
# 114  Percent of adults aged 18 years and older who have obesity
# 115  Percent of adults who report consuming vegetables less than one time daily
# 116  Percent of adults aged 18 years and older who have obesity
# 117  Percent of adults who report consuming fruit less than one time daily
# 118  Percent of adults aged 18 years and older who have an overweight classification
# 119  Percent of adults who engage in no leisure-time physical activity
# 120  Percent of adults aged 18 years and older who have an overweight classification
# 121  Percent of adults who report consuming fruit less than one time daily
# 122  Percent of adults who engage in no leisure-time physical activity
# 123  Percent of adults who report consuming vegetables less than one time daily
# 124  Percent of adults aged 18 years and older who have obesity
# 125  Percent of adults aged 18 years and older who have an overweight classification
# 126  Percent of adults who engage in no leisure-time physical activity
# 127  Percent of adults who report consuming vegetables less than one time daily
# 128  Percent of adults aged 18 years and older who have obesity
# 129  Percent of adults who report consuming fruit less than one time daily
# 130  Percent of adults aged 18 years and older who have obesity
# 131  Percent of adults who report consuming vegetables less than one time daily
# 132  Percent of adults who engage in no leisure-time physical activity
# 133  Percent of adults aged 18 years and older who have an overweight classification
# 134  Percent of adults who report consuming fruit less than one time daily
# 135  Percent of adults who engage in no leisure-time physical activity
# 136  Percent of adults aged 18 years and older who have an overweight classification
# 137  Percent of adults aged 18 years and older who have obesity
# 138  Percent of adults who report consuming fruit less than one time daily
# 139  Percent of adults who report consuming vegetables less than one time daily
#
#      data_value  sample_size    age_years
# 0    19.3        254.0        18 - 24
# 1    28.5        232.0        18 - 24
# 2    24.7        219.0        18 - 24
# 3    25.4        232.0        18 - 24
# 4    44.8        223.0        18 - 24
# 5    20.3        410.0        25 - 34
# 6    46.6        433.0        25 - 34
# 7    23.3        475.0        25 - 34
# 8    49.4        419.0        25 - 34
# 9    21.1        433.0        25 - 34
# 10   44.5        507.0        35 - 44
# 11   22.4        553.0        35 - 44
# 12   31.8        521.0        35 - 44
# 13   16.7        499.0        35 - 44
# 14   45.8        521.0        35 - 44
# 15   35.6        638.0        45 - 54
# 16   46.4        594.0        45 - 54
# 17   49.2        577.0        45 - 54
# 18   19.5        570.0        45 - 54
# 19   33.8        594.0        45 - 54
# 20   32.7        826.0        55 - 64
# 21   39.1        900.0        55 - 64
# 22   48.4        809.0        55 - 64
# 23   44.4        826.0        55 - 64
# 24   21.2        811.0        55 - 64
# 25   41.1        1642.0       65 or older
# 26   30.9        1641.0       65 or older
# 27   41.3        1758.0       65 or older
# 28   21.7        1607.0       65 or older
# 29   39.4        1641.0       65 or older
# 30   19.8        1671.0       NaN
# 31   34.3        1553.0       NaN
# 32   15.5        1555.0       NaN
# 33   40.5        1566.0       NaN
# 34   34.2        1553.0       NaN
# 35   27.9        1289.0       NaN
# 36   47.6        1177.0       NaN
# 37   31.6        1194.0       NaN
# 38   15.0        1149.0       NaN
# 39   42.6        1194.0       NaN
# 40   46.9        356.0        NaN
# 41   44.4        311.0        NaN
# 42   33.1        328.0        NaN
# 43   40.5        328.0        NaN
# 44   27.8        305.0        NaN
# 45   30.1        1165.0       NaN
# 46   41.1        1165.0       NaN
# 47   49.3        1113.0       NaN
# 48   27.3        1097.0       NaN
# 49   37.4        1245.0       NaN
# 50   18.4        2477.0       NaN
# 51   44.8        2503.0       NaN
# 52   41.6        2494.0       NaN
# 53   27.7        2494.0       NaN
# 54   35.7        2752.0       NaN
# 55   38.0        1753.0       NaN
# 56   47.1        1674.0       NaN
# 57   36.3        1753.0       NaN
# 58   26.9        1826.0       NaN
# 59   22.9        1639.0       NaN
# 60   30.1        409.0        NaN
# 61   25.9        387.0        NaN
# 62   48.0        393.0        NaN
# 63   46.4        430.0        NaN
# 64   40.8        409.0        NaN
# 65   33.0        495.0        NaN
# 66   30.7        475.0        NaN
# 67   23.4        453.0        NaN
# 68   46.2        475.0        NaN
# 69   42.4        457.0        NaN
# 70   19.6        474.0        NaN
# 71   46.4        504.0        NaN
# 72   28.5        504.0        NaN
# 73   49.1        486.0        NaN
# 74   32.9        522.0        NaN
# 75   20.8        589.0        NaN
# 76   47.7        559.0        NaN
# 77   19.2        551.0        NaN
# 78   30.9        569.0        NaN
# 79   42.8        569.0        NaN
# 80   24.8        455.0        NaN
# 81   49.7        440.0        NaN
# 82   35.5        441.0        NaN
# 83   13.9        434.0        NaN
# 84   40.3        441.0        NaN
# 85   47.2        252.0        NaN
# 86   27.0        273.0        NaN
# 87   36.8        246.0        NaN
# 88   40.8        273.0        NaN
# 89   45.2        279.0        NaN
# 90   30.3        1808.0       NaN
# 91   34.1        1576.0       NaN
# 92   43.3        1590.0       NaN
# 93   18.4        1571.0       NaN
# 94   34.2        1576.0       NaN
# 95   31.9        4247.0       NaN
# 96   31.5        4578.0       NaN
# 97   45.9        4177.0       NaN
# 98   39.9        4247.0       NaN
# 99   20.6        4116.0       NaN
# 100  35.3        81.0         NaN
# 101  45.8        81.0         NaN
# 102  16.6        76.0         NaN
# 103  25.4        88.0         NaN
# 104  45.6        80.0         NaN
# 105 NaN         NaN           NaN
# 106 NaN         NaN           NaN
# 107 NaN         NaN           NaN
# 108 NaN         NaN           NaN
# 109 NaN         NaN           NaN
# 110  35.0        1172.0       NaN
# 111  26.5        1076.0       NaN
# 112  27.1        1031.0       NaN
# 113  37.5        1039.0       NaN
# 114  49.7        1076.0       NaN
# 115  37.6        75.0         NaN
# 116  38.8        69.0         NaN
# 117  42.6        72.0         NaN
# 118  36.6        69.0         NaN
# 119  22.8        84.0         NaN
# 120 NaN         NaN           NaN
# 121 NaN         NaN           NaN
# 122 NaN         NaN           NaN
# 123 NaN         NaN           NaN
# 124 NaN         NaN           NaN
# 125 NaN         NaN           NaN
# 126 NaN         NaN           NaN
# 127 NaN         NaN           NaN
# 128 NaN         NaN           NaN
# 129 NaN         NaN           NaN
# 130 NaN         NaN           NaN
# 131 NaN         NaN           NaN
# 132 NaN         NaN           NaN
# 133 NaN         NaN           NaN
# 134 NaN         NaN           NaN
# 135  31.0        3080.0       NaN
# 136  33.3        2888.0       NaN
# 137  36.8        2888.0       NaN
# 138  49.6        2854.0       NaN
# 139  17.3        2805.0       NaN

# %%
#https://stackoverflow.com/questions/26246864/restoring-the-default-display-context-in-pandas
#reset default values
pd.reset_option('all')
